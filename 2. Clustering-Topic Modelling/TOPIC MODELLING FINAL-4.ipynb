# %%
#!pip install pandas

# %%
#####-----------------------------CRIAR O DATA SET A TRABALHAR ---------------------------------------##################

# %%
import pandas as pd

# %%
filename = 'C:/Users/Bruna/Desktop/deus7.csv'
df = pd.read_csv(filename, sep=',', encoding='utf8')
df.head(50)
# Out:
# C:\Users\Bruna\AppData\Local\Temp\ipykernel_15292\160407028.py:2: DtypeWarning: Columns (7,13,14,15,16,35,37,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, sep=',', encoding='utf8')
#     Unnamed: 0                 createTime hashtags tags tags_full_name  \
# 0            1  2022-06-20 20:53:25+00:00      NaN  NaN            NaN
# 1            2  2022-06-20 20:53:26+00:00      NaN  NaN            NaN
# 2            3  2022-06-20 20:53:27+00:00      NaN  NaN            NaN
# 3            4  2022-06-20 14:26:26+00:00      NaN  NaN            NaN
# 4            5  2022-06-21 08:02:49+00:00      NaN  NaN            NaN
# 5            6  2022-06-21 08:02:37+00:00      NaN  NaN            NaN
# 6            7  2022-06-21 08:02:28+00:00      NaN  NaN            NaN
# 7            8  2022-06-21 08:05:47+00:00      NaN  NaN            NaN
# 8            9  2022-06-21 08:12:55+00:00      NaN  NaN            NaN
# 9           10  2022-06-21 08:06:23+00:00      NaN  NaN            NaN
# 10          11  2022-06-20 15:19:59+00:00      NaN  NaN            NaN
# 11          12  2022-06-20 15:19:58+00:00      NaN  NaN            NaN
# 12          13  2022-06-20 12:55:11+00:00      NaN  NaN            NaN
# 13          14  2022-06-20 11:55:58+00:00      NaN  NaN            NaN
# 14          15  2022-06-20 11:54:58+00:00      NaN  NaN            NaN
# 15          16  2022-06-21 07:34:38+00:00      NaN  NaN            NaN
# 16          17  2022-06-21 07:34:39+00:00      NaN  NaN            NaN
# 17          18  2022-06-20 12:16:18+00:00      NaN  NaN            NaN
# 18          19  2022-06-20 15:14:57+00:00      NaN  NaN            NaN
# 19          20  2022-06-20 19:39:16+00:00      NaN  NaN            NaN
# 20          21  2022-06-20 15:51:59+00:00      NaN  NaN            NaN
# 21          22  2022-06-21 07:23:54+00:00      NaN  NaN            NaN
# 22          23  2022-06-21 07:23:53+00:00      NaN  NaN            NaN
# 23          24  2022-06-21 07:16:22+00:00      NaN  NaN            NaN
# 24          25  2022-06-20 19:24:26+00:00      NaN  NaN            NaN
# 25          26  2022-06-21 08:51:36+00:00      NaN  NaN            NaN
# 26          27  2022-06-21 09:37:56+00:00      NaN  NaN            NaN
# 27          28  2022-06-21 07:26:41+00:00      NaN  NaN            NaN
# 28          29  2022-06-21 08:51:35+00:00      NaN  NaN            NaN
# 29          30  2022-06-20 19:16:47+00:00      NaN  NaN            NaN
# 30          31  2022-06-21 07:45:53+00:00      NaN  NaN            NaN
# 31          32  2022-06-21 07:45:52+00:00      NaN  NaN            NaN
# 32          33  2022-06-20 19:18:51+00:00      NaN  NaN            NaN
# 33          34  2022-06-20 20:27:02+00:00      NaN  NaN            NaN
# 34          35  2022-06-20 13:59:39+00:00      NaN  NaN            NaN
# 35          36  2022-06-20 19:29:41+00:00      NaN  NaN            NaN
# 36          37  2022-06-21 07:28:38+00:00      NaN  NaN            NaN
# 37          38  2022-06-21 07:28:40+00:00      NaN  NaN            NaN
# 38          39  2022-06-21 07:28:39+00:00      NaN  NaN            NaN
# 39          40  2022-06-20 20:53:49+00:00      NaN  NaN            NaN
# 40          41  2022-06-20 20:53:50+00:00      NaN  NaN            NaN
# 41          42  2022-06-20 17:22:39+00:00      NaN  NaN            NaN
# 42          43  2022-06-21 07:47:34+00:00      NaN  NaN            NaN
# 43          44  2022-06-21 07:47:32+00:00      NaN  NaN            NaN
# 44          45  2022-06-21 07:49:02+00:00      NaN  NaN            NaN
# 45          46  2022-06-21 07:47:35+00:00      NaN  NaN            NaN
# 46          47  2022-06-21 07:47:33+00:00      NaN  NaN            NaN
# 47          48  2022-06-20 21:15:01+00:00      NaN  NaN            NaN
# 48          49  2022-06-20 21:16:39+00:00      NaN  NaN            NaN
# 49          50  2022-06-20 21:16:23+00:00      NaN  NaN            NaN
#
#    tags_verified  isPaidPartnership text productType  InstagramUserId  ...  \
# 0            NaN              False  NaN       story              149  ...
# 1            NaN              False  NaN       story              149  ...
# 2            NaN              False  NaN       story              149  ...
# 3            NaN              False  NaN       story              157  ...
# 4            NaN              False  NaN       story              158  ...
# 5            NaN              False  NaN       story              158  ...
# 6            NaN              False  NaN       story              158  ...
# 7            NaN              False  NaN       story              158  ...
# 8            NaN              False  NaN       story              158  ...
# 9            NaN              False  NaN       story              158  ...
# 10           NaN              False  NaN       story              164  ...
# 11           NaN              False  NaN       story              164  ...
# 12           NaN              False  NaN       story              165  ...
# 13           NaN              False  NaN       story              165  ...
# 14           NaN              False  NaN       story              165  ...
# 15           NaN              False  NaN       story              172  ...
# 16           NaN              False  NaN       story              172  ...
# 17           NaN              False  NaN       story              188  ...
# 18           NaN              False  NaN       story              188  ...
# 19           NaN              False  NaN       story              189  ...
# 20           NaN              False  NaN       story              189  ...
# 21           NaN              False  NaN       story              193  ...
# 22           NaN              False  NaN       story              193  ...
# 23           NaN              False  NaN       story              193  ...
# 24           NaN              False  NaN       story              193  ...
# 25           NaN              False  NaN       story              193  ...
# 26           NaN              False  NaN       story              193  ...
# 27           NaN              False  NaN       story              193  ...
# 28           NaN              False  NaN       story              193  ...
# 29           NaN              False  NaN       story              195  ...
# 30           NaN              False  NaN       story              202  ...
# 31           NaN              False  NaN       story              202  ...
# 32           NaN              False  NaN       story              211  ...
# 33           NaN              False  NaN       story              211  ...
# 34           NaN              False  NaN       story              212  ...
# 35           NaN              False  NaN       story              213  ...
# 36           NaN              False  NaN       story              213  ...
# 37           NaN              False  NaN       story              213  ...
# 38           NaN              False  NaN       story              213  ...
# 39           NaN              False  NaN       story              214  ...
# 40           NaN              False  NaN       story              214  ...
# 41           NaN              False  NaN       story              218  ...
# 42           NaN              False  NaN       story              223  ...
# 43           NaN              False  NaN       story              223  ...
# 44           NaN              False  NaN       story              223  ...
# 45           NaN              False  NaN       story              223  ...
# 46           NaN              False  NaN       story              223  ...
# 47           NaN              False  NaN       story              226  ...
# 48           NaN              False  NaN       story              226  ...
# 49           NaN              False  NaN       story              226  ...
#
#    MONEY  NORP  ORDINAL ORG PERCENT PERSON PRODUCT  QUANTITY TIME  WORK_OF_ART
# 0    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 1    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 2    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 3    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 4    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 5    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 6    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 7    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 8    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 9    NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 10   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 11   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 12   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 13   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 14   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 15   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 16   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 17   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 18   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 19   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 20   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 21   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 22   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 23   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 24   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 25   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 26   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 27   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 28   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 29   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 30   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 31   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 32   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 33   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 34   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 35   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 36   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 37   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 38   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 39   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 40   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 41   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 42   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 43   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 44   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 45   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 46   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 47   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 48   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
# 49   NaN   NaN      NaN NaN     NaN    NaN     NaN       NaN  NaN          NaN
#
# [50 rows x 59 columns]

# %%
df2=df.filter(['Unnamed: 0','desc','translation'], axis=1)
df2.head(100)
# Out:
#     Unnamed: 0 desc translation
# 0            1  NaN         NaN
# 1            2  NaN         NaN
# 2            3  NaN         NaN
# 3            4  NaN         NaN
# 4            5  NaN         NaN
# ..         ...  ...         ...
# 95          96  NaN         NaN
# 96          97  NaN         NaN
# 97          98  NaN         NaN
# 98          99  NaN         NaN
# 99         100  NaN         NaN
#
# [100 rows x 3 columns]

# %%
df2.translation=df2.translation.astype(str)

# %%
df3 = df2.dropna()

# %%
################# In topic modeling with gensim, 
#################  we followed a structured workflow to build an insightful topic model based on
##################### the Latent Dirichlet Allocation (LDA) algorithm.

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\bruna\anaconda3\lib\site-packages (3.5.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (4.64.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (8.1.7)
# Requirement already satisfied: jinja2 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (1.1.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (6.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (2.4.5)
# Requirement already satisfied: setuptools in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (61.2.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (1.21.5)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (1.10.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bruna\anaconda3\lib\site-packages (from spacy) (3.0.11)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bruna\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\bruna\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bruna\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bruna\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: colorama in c:\users\bruna\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bruna\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bruna\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)

# %%
 pip install --user --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\bruna\appdata\roaming\python\python39\site-packages (22.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pattern
# Out:
# Requirement already satisfied: pattern in c:\users\bruna\anaconda3\lib\site-packages (3.6)
# Requirement already satisfied: python-docx in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (0.8.11)
# Requirement already satisfied: lxml in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (4.8.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (4.11.1)
# Requirement already satisfied: numpy in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (1.21.5)
# Requirement already satisfied: pdfminer.six in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (20221105)
# Requirement already satisfied: scipy in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (1.7.3)
# Requirement already satisfied: mysqlclient in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (2.1.1)
# Requirement already satisfied: backports.csv in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (1.0.7)
# Requirement already satisfied: requests in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (2.27.1)
# Requirement already satisfied: future in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (0.18.2)
# Requirement already satisfied: cherrypy in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (18.8.0)
# Requirement already satisfied: feedparser in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (6.0.10)
# Requirement already satisfied: nltk in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (3.7)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bruna\anaconda3\lib\site-packages (from beautifulsoup4->pattern) (2.3.1)
# Requirement already satisfied: jaraco.collections in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (3.8.0)
# Requirement already satisfied: more-itertools in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (9.0.0)
# Requirement already satisfied: portend>=2.1.1 in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (3.1.0)
# Requirement already satisfied: cheroot>=8.2.1 in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (9.0.0)
# Requirement already satisfied: zc.lockfile in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (2.0)
# Requirement already satisfied: pywin32>=227 in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (302)
# Requirement already satisfied: sgmllib3k in c:\users\bruna\anaconda3\lib\site-packages (from feedparser->pattern) (1.0.0)
# Requirement already satisfied: joblib in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (2022.3.15)
# Requirement already satisfied: click in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (4.64.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from pdfminer.six->pattern) (2.0.4)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from pdfminer.six->pattern) (38.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruna\anaconda3\lib\site-packages (from requests->pattern) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruna\anaconda3\lib\site-packages (from requests->pattern) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bruna\anaconda3\lib\site-packages (from requests->pattern) (1.26.9)
# Requirement already satisfied: jaraco.functools in c:\users\bruna\anaconda3\lib\site-packages (from cheroot>=8.2.1->cherrypy->pattern) (3.5.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\bruna\anaconda3\lib\site-packages (from cheroot>=8.2.1->cherrypy->pattern) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\bruna\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.15.0)
# Requirement already satisfied: tempora>=1.8 in c:\users\bruna\anaconda3\lib\site-packages (from portend>=2.1.1->cherrypy->pattern) (5.2.1)
# Requirement already satisfied: colorama in c:\users\bruna\anaconda3\lib\site-packages (from click->nltk->pattern) (0.4.6)
# Requirement already satisfied: jaraco.text in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.collections->cherrypy->pattern) (3.11.0)
# Requirement already satisfied: jaraco.classes in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.collections->cherrypy->pattern) (3.2.3)
# Requirement already satisfied: setuptools in c:\users\bruna\anaconda3\lib\site-packages (from zc.lockfile->cherrypy->pattern) (61.2.0)
# Requirement already satisfied: pycparser in c:\users\bruna\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.21)
# Requirement already satisfied: pytz in c:\users\bruna\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern) (2021.3)
# Requirement already satisfied: inflect in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (6.0.2)
# Requirement already satisfied: jaraco.context>=4.1 in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (4.3.0)
# Requirement already satisfied: autocommand in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (2.2.2)
# Requirement already satisfied: pydantic>=1.9.1 in c:\users\bruna\anaconda3\lib\site-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (1.10.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\bruna\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (4.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U pattern
# Out:
# Requirement already satisfied: pattern in c:\users\bruna\anaconda3\lib\site-packages (3.6)
# Requirement already satisfied: feedparser in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (6.0.10)
# Requirement already satisfied: lxml in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (4.8.0)
# Requirement already satisfied: backports.csv in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (1.0.7)
# Requirement already satisfied: python-docx in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (0.8.11)
# Requirement already satisfied: scipy in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (1.7.3)
# Requirement already satisfied: future in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (0.18.2)
# Requirement already satisfied: mysqlclient in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (2.1.1)
# Requirement already satisfied: nltk in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (3.7)
# Requirement already satisfied: cherrypy in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (18.8.0)
# Requirement already satisfied: numpy in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (1.21.5)
# Requirement already satisfied: pdfminer.six in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (20221105)
# Requirement already satisfied: requests in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\bruna\anaconda3\lib\site-packages (from pattern) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bruna\anaconda3\lib\site-packages (from beautifulsoup4->pattern) (2.3.1)
# Requirement already satisfied: pywin32>=227 in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (302)
# Requirement already satisfied: jaraco.collections in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (3.8.0)
# Requirement already satisfied: zc.lockfile in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (2.0)
# Requirement already satisfied: portend>=2.1.1 in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (3.1.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: more-itertools in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (9.0.0)
# Requirement already satisfied: cheroot>=8.2.1 in c:\users\bruna\anaconda3\lib\site-packages (from cherrypy->pattern) (9.0.0)
# Requirement already satisfied: sgmllib3k in c:\users\bruna\anaconda3\lib\site-packages (from feedparser->pattern) (1.0.0)
# Requirement already satisfied: click in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (8.0.4)
# Requirement already satisfied: joblib in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (2022.3.15)
# Requirement already satisfied: tqdm in c:\users\bruna\anaconda3\lib\site-packages (from nltk->pattern) (4.64.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from pdfminer.six->pattern) (38.0.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from pdfminer.six->pattern) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruna\anaconda3\lib\site-packages (from requests->pattern) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bruna\anaconda3\lib\site-packages (from requests->pattern) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruna\anaconda3\lib\site-packages (from requests->pattern) (2021.10.8)
# Requirement already satisfied: jaraco.functools in c:\users\bruna\anaconda3\lib\site-packages (from cheroot>=8.2.1->cherrypy->pattern) (3.5.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\bruna\anaconda3\lib\site-packages (from cheroot>=8.2.1->cherrypy->pattern) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\bruna\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six->pattern) (1.15.0)
# Requirement already satisfied: tempora>=1.8 in c:\users\bruna\anaconda3\lib\site-packages (from portend>=2.1.1->cherrypy->pattern) (5.2.1)
# Requirement already satisfied: colorama in c:\users\bruna\anaconda3\lib\site-packages (from click->nltk->pattern) (0.4.6)
# Requirement already satisfied: jaraco.text in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.collections->cherrypy->pattern) (3.11.0)
# Requirement already satisfied: jaraco.classes in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.collections->cherrypy->pattern) (3.2.3)
# Requirement already satisfied: setuptools in c:\users\bruna\anaconda3\lib\site-packages (from zc.lockfile->cherrypy->pattern) (61.2.0)
# Requirement already satisfied: pycparser in c:\users\bruna\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern) (2.21)
# Requirement already satisfied: pytz in c:\users\bruna\anaconda3\lib\site-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern) (2021.3)
# Requirement already satisfied: jaraco.context>=4.1 in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (4.3.0)
# Requirement already satisfied: autocommand in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (2.2.2)
# Requirement already satisfied: inflect in c:\users\bruna\anaconda3\lib\site-packages (from jaraco.text->jaraco.collections->cherrypy->pattern) (6.0.2)
# Requirement already satisfied: pydantic>=1.9.1 in c:\users\bruna\anaconda3\lib\site-packages (from inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (1.10.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\bruna\anaconda3\lib\site-packages (from pydantic>=1.9.1->inflect->jaraco.text->jaraco.collections->cherrypy->pattern) (4.4.0)

# %%
pip install pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in c:\users\bruna\anaconda3\lib\site-packages (3.3.1)
# Requirement already satisfied: sklearn in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (0.0.post1)
# Requirement already satisfied: setuptools in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (61.2.0)
# Requirement already satisfied: funcy in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (1.17)
# Requirement already satisfied: joblib in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (1.1.0)
# Requirement already satisfied: scipy in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (1.7.3)
# Requirement already satisfied: gensim in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (4.1.2)
# Requirement already satisfied: numexpr in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (2.8.1)
# Requirement already satisfied: pandas>=1.2.0 in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (2.11.3)
# Requirement already satisfied: scikit-learn in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (1.0.2)
# Requirement already satisfied: future in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (0.18.2)
# Requirement already satisfied: numpy>=1.20.0 in c:\users\bruna\anaconda3\lib\site-packages (from pyLDAvis) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bruna\anaconda3\lib\site-packages (from pandas>=1.2.0->pyLDAvis) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bruna\anaconda3\lib\site-packages (from pandas>=1.2.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\bruna\anaconda3\lib\site-packages (from gensim->pyLDAvis) (6.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bruna\anaconda3\lib\site-packages (from jinja2->pyLDAvis) (2.0.1)
# Requirement already satisfied: packaging in c:\users\bruna\anaconda3\lib\site-packages (from numexpr->pyLDAvis) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from scikit-learn->pyLDAvis) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\bruna\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bruna\anaconda3\lib\site-packages (from packaging->numexpr->pyLDAvis) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import these modules
from nltk.stem import WordNetLemmatizer
  
lemmatizer = WordNetLemmatizer()

# %%
 pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\bruna\appdata\roaming\python\python39\site-packages (22.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
# !{sys.executable} -m spacy download en
import re, numpy as np, pandas as pd
from pprint import pprint

# Gensim
import gensim, spacy, logging, warnings
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt


# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use', 'not', 'would', 'say', 'could', '_', 'be', 'know', 'good', 'go', 'get', 'do', 'done', 'try', 'many', 'some', 'nice', 'thank', 'think', 'see', 'rather', 'easy', 'easily', 'lot', 'lack', 'make', 'want', 'seem', 'run', 'need', 'even', 'right', 'line', 'even', 'also', 'may', 'take', 'come'])


# %matplotlib inline
warnings.filterwarnings("ignore",category=DeprecationWarning)
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
# Out:
# C:\Users\Bruna\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
###########################  Tokenize Sentences and Clean ######################

# %%
def sent_to_words(sentences):
    for sent in sentences:
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub("\'", "", sent)  # remove single quotes
        sent = gensim.utils.simple_preprocess(str(sent), deacc=True) 
        yield(sent)  

# Convert to list
data = df3.translation.values.tolist()
data_words = list(sent_to_words(data))
print(data_words[:1])
# [['from', 'irwin', 'arnstein', 'subject', 're', 'recommendation', 'on', 'duc', 'summary', 'whats', 'it', 'worth', 'distribution', 'usa', 'expires', 'sat', 'may', 'gmt', ...trucated...]]
# Out:
# [['pjalma', 'day', 'zara', 'codes', 'top', 'shorts']]

# %%
##############  Build the Bigram, Trigram Models and Lemmatize #################

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      --------------------------------------- 12.8/12.8 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\bruna\anaconda3\lib\site-packages (from en-core-web-sm==3.5.0) (3.5.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.21.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.7)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.11)
# Requirement already satisfied: setuptools in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (61.2.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: jinja2 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bruna\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bruna\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\bruna\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bruna\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bruna\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bruna\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\bruna\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bruna\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bruna\anaconda3\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# !python3 -m spacy download en  # run in terminal once

def process_words(texts, stop_words=stop_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """Remove Stopwords, Form Bigrams, Trigrams and Lemmatization"""
    texts = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    texts_out = []
    nlp = spacy.load("en_core_web_sm")
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    # remove stopwords once more after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts_out]    
    return texts_out

data_ready = process_words(data_words)  # processed Text Data!

# %%
##########  Build the Topic Model ##################

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=4, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=10,
                                           passes=10,
                                           alpha='symmetric',
                                           iterations=100,
                                           per_word_topics=True)

pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.023*"day" + 0.017*"love" + 0.015*"life" + 0.015*"time" + 0.012*"year" + '
#   '0.010*"always" + 0.010*"today" + 0.008*"live" + 0.007*"people" + '
#   '0.007*"already"'),
#  (1,
#   '0.021*"skin" + 0.014*"eat" + 0.011*"recipe" + 0.010*"add" + 0.009*"water" + '
#   '0.009*"pub" + 0.009*"perfect" + 0.009*"light" + 0.008*"face" + '
#   '0.008*"simple"'),
#  (2,
#   '0.034*"photo" + 0.026*"end" + 0.026*"new" + 0.025*"way" + 0.023*"look" + '
#   '0.021*"first" + 0.019*"find" + 0.014*"dream" + 0.014*"trip" + 0.013*"full"'),
#  (3,
#   '0.021*"summer" + 0.021*"beauty" + 0.014*"story" + 0.013*"nature" + '
#   '0.012*"dress" + 0.011*"post" + 0.011*"outfit" + 0.011*"prozi" + '
#   '0.010*"wear" + 0.010*"favorite"')]

# %%
###########    What is the Dominant topic and its percentage contribution in each document  ####################

# %%
def format_topics_sentences(ldamodel=None, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data_ready)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.head(10)
# Out:
# C:\Users\Bruna\AppData\Local\Temp\ipykernel_15292\1516627226.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
# C:\Users\Bruna\AppData\Local\Temp\ipykernel_15292\1516627226.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0               2              0.2501
# 1            1               1              0.5652
# 2            2               3              0.4167
# 3            3               1              0.3228
# 4            4               2              0.5737
# 5            5               3              0.2513
# 6            6               2              0.4750
# 7            7               2              0.6249
# 8            8               1              0.4713
# 9            9               2              0.6054
#
#                                             Keywords  \
# 0  photo, end, new, way, look, first, find, dream...
# 1  skin, eat, recipe, add, water, pub, perfect, l...
# 2  summer, beauty, story, nature, dress, post, ou...
# 3  skin, eat, recipe, add, water, pub, perfect, l...
# 4  photo, end, new, way, look, first, find, dream...
# 5  summer, beauty, story, nature, dress, post, ou...
# 6  photo, end, new, way, look, first, find, dream...
# 7  photo, end, new, way, look, first, find, dream...
# 8  skin, eat, recipe, add, water, pub, perfect, l...
# 9  photo, end, new, way, look, first, find, dream...
#
#                                                 Text
# 0                            [day, code, top, short]
# 1                        [quick, grwm, makeup, hair]
# 2                                       [feel, ootd]
# 3  [lip, option, prefer, really, first, suit, pro...
# 4             [explore, palma, mallorca, zimmermann]
# 5                    [basic, always, ootd, mallorca]
# 6              [short, zara, top, eva, flat, sandal]
# 7                                         [mallorca]
# 8  [airwrap, slowly, become, friend, dyson, airwr...
# 9                     [visit, ller, mallorca, short]

# %%
#######################  The most representative sentence for each topic ############################

# %%
# Display setting to show more characters in column
pd.options.display.max_colwidth = 100

sent_topics_sorteddf_mallet = pd.DataFrame()
sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=False).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Representative Text"]

# Show
sent_topics_sorteddf_mallet.head(10)
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0          0              0.9836
# 1          1              0.9694
# 2          2              0.9397
# 3          3              0.9671
#
#                                                                     Keywords  \
# 0          day, love, life, time, year, always, today, live, people, already
# 1           skin, eat, recipe, add, water, pub, perfect, light, face, simple
# 2                 photo, end, new, way, look, first, find, dream, trip, full
# 3  summer, beauty, story, nature, dress, post, outfit, prozi, wear, favorite
#
#                                                                                    Representative Text
# 0  [dear, child, create, extent, meet, expectation, lawyer, economist, instead, always, give, real,...
# 1  [ingredient, chicken, cube, squeeze, lemon, juice, garlic, powder_tsp, onion, powder, pasta, sau...
# 2  [etapa, total, geral, elite, orbea, myorbea, orbeaoiz, aquih, sponseryourbest, evoc, evocbike, e...
# 3  [sete, cidade, olhoportugue, visualsgang, earthcapture, illgrammer, moodygram, letsgosomewhere, ...

# %%
#######################  Frequency Distribution of Word Counts in Documents #############################

# %%
doc_lens = [len(d) for d in df_dominant_topic.Text]

# Plot
plt.figure(figsize=(16,7), dpi=160)
plt.hist(doc_lens, bins = 200, color='navy')
plt.text(750, 100, "Mean   : " + str(round(np.mean(doc_lens))))
plt.text(750,  90, "Median : " + str(round(np.median(doc_lens))))
plt.text(750,  80, "Stdev   : " + str(round(np.std(doc_lens))))
plt.text(750,  70, "1%ile    : " + str(round(np.quantile(doc_lens, q=0.01))))
plt.text(750,  60, "99%ile  : " + str(round(np.quantile(doc_lens, q=0.99))))

plt.gca().set(xlim=(0, 200), ylabel='Number of Documents', xlabel='Document Word Count')
plt.tick_params(size=16)
plt.xticks(np.linspace(0,200,9))
plt.title('Distribution of Document Word Counts', fontdict=dict(size=22))
plt.show()

# %%
import seaborn as sns
import matplotlib.colors as mcolors
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

fig, axes = plt.subplots(2,2,figsize=(16,14), dpi=160, sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):    
    df_dominant_topic_sub = df_dominant_topic.loc[df_dominant_topic.Dominant_Topic == i, :]
    doc_lens = [len(d) for d in df_dominant_topic_sub.Text]
    ax.hist(doc_lens, bins = 200, color=cols[i])
    ax.tick_params(axis='y', labelcolor=cols[i], color=cols[i])
    sns.kdeplot(doc_lens, color="black", shade=False, ax=ax.twinx())
    ax.set(xlim=(0, 200), xlabel='Document Word Count')
    ax.set_ylabel('Number of Documents', color=cols[i])
    ax.set_title('Topic: '+str(i), fontdict=dict(size=16, color=cols[i]))

fig.tight_layout()
fig.subplots_adjust(top=0.90)
plt.xticks(np.linspace(0,200,9))
fig.suptitle('Distribution of Document Word Counts by Dominant Topic', fontsize=22)
plt.show()

# %%
################# Word Clouds of Top N Keywords in Each Topic########################

# %%
# 1. Wordcloud of Top N words in each topic
from matplotlib import pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import matplotlib.colors as mcolors

cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]  # more colors: 'mcolors.XKCD_COLORS'

cloud = WordCloud(stopwords=stop_words,
                  background_color='white',
                  width=2500,
                  height=1800,
                  max_words=10,
                  colormap='tab10',
                  color_func=lambda *args, **kwargs: cols[i],
                  prefer_horizontal=1.0)

topics = lda_model.show_topics(formatted=False)

fig, axes = plt.subplots(2, 2, figsize=(10,10), sharex=True, sharey=True)

for i, ax in enumerate(axes.flatten()):
    fig.add_subplot(ax)
    topic_words = dict(topics[i][1])
    cloud.generate_from_frequencies(topic_words, max_font_size=300)
    plt.gca().imshow(cloud)
    plt.gca().set_title('Topic ' + str(i), fontdict=dict(size=16))
    plt.gca().axis('off')


plt.subplots_adjust(wspace=0, hspace=0)
plt.axis('off')
plt.margins(x=0, y=0)
plt.tight_layout()
plt.show()

# %%
###########################  Word Counts of Topic Keywords ###################

# %%
from collections import Counter
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 2, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()
# Out:
# C:\Users\Bruna\AppData\Local\Temp\ipykernel_15292\2855870167.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# C:\Users\Bruna\AppData\Local\Temp\ipykernel_15292\2855870167.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# C:\Users\Bruna\AppData\Local\Temp\ipykernel_15292\2855870167.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
# C:\Users\Bruna\AppData\Local\Temp\ipykernel_15292\2855870167.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')

# %%
##################  Sentence Chart Colored by Topic #################################

# %%
# Sentence Coloring of N Sentences
from matplotlib.patches import Rectangle

def sentences_chart(lda_model=lda_model, corpus=corpus, start = 0, end = 13):
    corp = corpus[start:end]
    mycolors = [color for name, color in mcolors.TABLEAU_COLORS.items()]

    fig, axes = plt.subplots(end-start, 1, figsize=(20, (end-start)*0.95), dpi=160)       
    axes[0].axis('off')
    for i, ax in enumerate(axes):
        if i > 0:
            corp_cur = corp[i-1] 
            topic_percs, wordid_topics, wordid_phivalues = lda_model[corp_cur]
            word_dominanttopic = [(lda_model.id2word[wd], topic[0]) for wd, topic in wordid_topics]    
            ax.text(0.01, 0.5, "Doc " + str(i-1) + ": ", verticalalignment='center',
                    fontsize=16, color='black', transform=ax.transAxes, fontweight=700)

            # Draw Rectange
            topic_percs_sorted = sorted(topic_percs, key=lambda x: (x[1]), reverse=True)
            ax.add_patch(Rectangle((0.0, 0.05), 0.99, 0.90, fill=None, alpha=1, 
                                   color=mycolors[topic_percs_sorted[0][0]], linewidth=2))

            word_pos = 0.06
            for j, (word, topics) in enumerate(word_dominanttopic):
                if j < 14:
                    ax.text(word_pos, 0.5, word,
                            horizontalalignment='left',
                            verticalalignment='center',
                            fontsize=16, color=mycolors[topics],
                            transform=ax.transAxes, fontweight=700)
                    word_pos += .009 * len(word)  # to move the word for the next iter
                    ax.axis('off')
            ax.text(word_pos, 0.5, '. . .',
                    horizontalalignment='left',
                    verticalalignment='center',
                    fontsize=16, color='black',
                    transform=ax.transAxes)       

    plt.subplots_adjust(wspace=0, hspace=0)
    plt.suptitle('Sentence Topic Coloring for Documents: ' + str(start) + ' to ' + str(end-2), fontsize=22, y=0.95, fontweight=700)
    plt.tight_layout()
    plt.show()

sentences_chart()

# %%
###############  What are the most discussed topics in the documents? ###################

# %%
# Sentence Coloring of N Sentences
def topics_per_document(model, corpus, start=0, end=1):
    corpus_sel = corpus[start:end]
    dominant_topics = []
    topic_percentages = []
    for i, corp in enumerate(corpus_sel):
        topic_percs, wordid_topics, wordid_phivalues = model[corp]
        dominant_topic = sorted(topic_percs, key = lambda x: x[1], reverse=True)[0][0]
        dominant_topics.append((i, dominant_topic))
        topic_percentages.append(topic_percs)
    return(dominant_topics, topic_percentages)

dominant_topics, topic_percentages = topics_per_document(model=lda_model, corpus=corpus, end=-1)            

# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])
dominant_topic_in_each_doc = df.groupby('Dominant_Topic').size()
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()

# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in lda_model.show_topics(formatted=False) 
                                 for j, (topic, wt) in enumerate(topics) if j < 3]

df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(', \n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
from matplotlib.ticker import FuncFormatter

# Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
ax1.set_ylim(0, 1000)

# Topic Distribution by Topic Weights
ax2.bar(x='index', height='count', data=df_topic_weightage_by_doc, width=.5, color='steelblue')
ax2.set_xticks(range(df_topic_weightage_by_doc.index.unique().__len__()))
ax2.xaxis.set_major_formatter(tick_formatter)
ax2.set_title('Number of Documents by Topic Weightage', fontdict=dict(size=10))

plt.show()

# %%
#############################  t-SNE Clustering Chart ###############################

# %%
# Get topic weights and dominant topics ------------
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook

# Get topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[corpus]):
    topic_weights.append([w for i, w in row_list[0]])

# Array of topic weights    
arr = pd.DataFrame(topic_weights).fillna(0).values

# Keep the well separated points (optional)
arr = arr[np.amax(arr, axis=1) > 0.35]

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)

# tSNE Dimension Reduction
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
tsne_lda = tsne_model.fit_transform(arr)

# Plot the Topic Clusters using Bokeh
output_notebook()
n_topics = 4
mycolors = np.array([color for name, color in mcolors.TABLEAU_COLORS.items()])
plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=900, plot_height=700)
plot.scatter(x=tsne_lda[:,0], y=tsne_lda[:,1], color=mycolors[topic_num])
show(plot)
# Out:
# C:\Users\Bruna\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 25145 samples in 0.081s...
# [t-SNE] Computed neighbors for 25145 samples in 1.679s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 25145
# [t-SNE] Computed conditional probabilities for sample 2000 / 25145
# [t-SNE] Computed conditional probabilities for sample 3000 / 25145
# [t-SNE] Computed conditional probabilities for sample 4000 / 25145
# [t-SNE] Computed conditional probabilities for sample 5000 / 25145
# [t-SNE] Computed conditional probabilities for sample 6000 / 25145
# [t-SNE] Computed conditional probabilities for sample 7000 / 25145
# [t-SNE] Computed conditional probabilities for sample 8000 / 25145
# [t-SNE] Computed conditional probabilities for sample 9000 / 25145
# [t-SNE] Computed conditional probabilities for sample 10000 / 25145
# [t-SNE] Computed conditional probabilities for sample 11000 / 25145
# [t-SNE] Computed conditional probabilities for sample 12000 / 25145
# [t-SNE] Computed conditional probabilities for sample 13000 / 25145
# [t-SNE] Computed conditional probabilities for sample 14000 / 25145
# [t-SNE] Computed conditional probabilities for sample 15000 / 25145
# [t-SNE] Computed conditional probabilities for sample 16000 / 25145
# [t-SNE] Computed conditional probabilities for sample 17000 / 25145
# [t-SNE] Computed conditional probabilities for sample 18000 / 25145
# [t-SNE] Computed conditional probabilities for sample 19000 / 25145
# [t-SNE] Computed conditional probabilities for sample 20000 / 25145
# [t-SNE] Computed conditional probabilities for sample 21000 / 25145
# [t-SNE] Computed conditional probabilities for sample 22000 / 25145
# [t-SNE] Computed conditional probabilities for sample 23000 / 25145
# [t-SNE] Computed conditional probabilities for sample 24000 / 25145
# [t-SNE] Computed conditional probabilities for sample 25000 / 25145
# [t-SNE] Computed conditional probabilities for sample 25145 / 25145
# [t-SNE] Mean sigma: 0.000000
# C:\Users\Bruna\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.292862
# [t-SNE] KL divergence after 1000 iterations: 1.070072
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="f0079c22-65ee-42e6-ba4f-bb4f05c48276" data-root-id="1003"></div>

# %%
#####################   pyLDAVis ##############################

# %%
import pyLDAvis.gensim_models
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# C:\Users\Bruna\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.361262 -0.017087       1        1  52.481633
# 1     -0.136934 -0.299902       2        1  18.005981
# 3     -0.136118  0.144705       3        1  14.987862
# 2     -0.088210  0.172284       4        1  14.524525, topic_info=         Term         Freq        Total Category  logprob  loglift
# 1170    photo  1775.000000  1775.000000  Default  30.0000  30.0000
# 1         day  4425.000000  4425.000000  Default  29.0000  29.0000
# 1014      end  1386.000000  1386.000000  Default  28.0000  28.0000
# 263       new  1360.000000  1360.000000  Default  27.0000  27.0000
# 81        way  1307.000000  1307.000000  Default  26.0000  26.0000
# ...       ...          ...          ...      ...      ...      ...
# 919       sun   300.106830   300.831854   Topic4  -5.1612   1.9269
# 16     filter   293.004133   293.812935   Topic4  -5.1851   1.9266
# 605   comfort   260.263749   261.017215   Topic4  -5.3036   1.9264
# 1393      sea   221.652414   222.328719   Topic4  -5.4642   1.9263
# 403     build   258.383100   259.257030   Topic4  -5.3109   1.9260
#
# [169 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 623       2  0.999389      add
# 3789      4  0.997579  algarve
# 509       1  0.999601  already
# 39        1  0.999821   always
# 298       3  0.999276  amazing
# ...     ...       ...      ...
# 203       1  0.999386     well
# 225       3  0.998474   winner
# 204       1  0.999179     work
# 1035      1  0.999620    world
# 544       1  0.999897     year
#
# [158 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 2, 4, 3])

# %%
lda_display = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary=lda_model.id2word)
pyLDAvis.display(lda_display)
# Out:
# C:\Users\Bruna\anaconda3\lib\site-packages\pyLDAvis\_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1529221453832922561745972566"></div>
# <script type="text/javascript">
#
# var ldavis_el1529221453832922561745972566_data = {"mdsDat": {"x": [0.3612617103062425, -0.13693398861899497, -0.13611795987540648, -0.08820976181184116], "y": [-0.017086590151937343, -0.29990161573791363, 0.14470466008298274, 0.1722835458068681], "topics": [1, 2, 3, 4], "cluster": [1, 1, 1, 1], "Freq": [52.4830692309074, 18.00644439139548, 14.98595317047371, 14.524533207223413]}, "tinfo": {"Term": ["photo", "day", "end", "new", "way", "look", "skin", "summer", "beauty", "first", "love", "find", "life", "time", "eat", "year", "story", "dream", "trip", "nature", "full", "believe", "always", "today", "recipe", "dress", "post", "outfit", "prozi", "beach", "day", "love", "life", "time", "year", "always", "today", "live", "people", "already", "friend", "thing", "well", "feel", "much", "happy", "child", "beautiful", "give", "work", "still", "little", "week", "never", "moment", "last", "great", "part", "continue", "world", "let", "leave", "skin", "eat", "recipe", "add", "water", "pub", "light", "perfect", "food", "face", "simple", "car", "ingredient", "serve", "salad", "taste", "super", "chocolate", "salt", "vibe", "apply", "tip", "hot", "fresh", "reduce", "cream", "heat", "cheese", "cut", "base", "product", "buy", "fill", "top", "makeup", "supplement", "put", "small", "summer", "beauty", "story", "nature", "dress", "outfit", "prozi", "wear", "post", "winner", "ootd", "comment", "photography", "azore", "view", "portuguese", "offer", "link", "site", "city", "picoftheday", "identify", "festival", "fitness", "com", "set", "participate", "cute", "store", "amazing", "discount", "available", "instadaily", "bodypositive", "favorite", "travel", "black", "bag", "photo", "end", "new", "way", "look", "first", "find", "dream", "trip", "full", "believe", "portugal", "beach", "show", "walk", "side", "weekend", "morning", "idea", "image", "dinner", "pink", "color", "pool", "wedding", "algarve", "sun", "filter", "comfort", "sea", "build"], "Freq": [1775.0, 4426.0, 1386.0, 1360.0, 1307.0, 1211.0, 1346.0, 1146.0, 1121.0, 1096.0, 3240.0, 1002.0, 2878.0, 2855.0, 919.0, 2248.0, 751.0, 731.0, 724.0, 679.0, 655.0, 646.0, 1941.0, 1908.0, 703.0, 633.0, 595.0, 592.0, 590.0, 581.0, 4425.300654957071, 3239.4995534821974, 2877.4433060247065, 2854.6293807496254, 2247.5814210277695, 1940.6787254597095, 1908.1251390515376, 1602.0599684048088, 1414.0902141306576, 1409.8700112837905, 1374.0464500513554, 1356.4127291178083, 1316.1218106593872, 1218.503050949955, 1207.2578348726001, 1278.6164197883536, 1128.2680173105296, 1271.6916947081388, 1131.018589326663, 1112.2303659994561, 1065.1830727183458, 1036.5399317271374, 1012.8249099376637, 951.6237800733899, 910.2797920124541, 915.2617093351869, 852.758154256833, 851.1051167386381, 840.8377761634176, 820.6261478868585, 905.9417792050382, 915.8082313270605, 1346.0648346959943, 918.3720911711555, 703.2820802013205, 619.6812378669508, 612.5712152490012, 595.3014626543418, 580.1569652462375, 580.1714050912906, 486.60519671969126, 526.1803410957797, 494.82506341170915, 490.5128362949934, 413.8503999263841, 403.3499439824076, 353.8918433960868, 366.8936248844964, 385.234523976837, 326.716266468381, 352.97862892756336, 351.27947000559715, 314.2601782039015, 286.654003888358, 293.32306747233355, 272.42401993065437, 316.71767066220065, 264.8059141454505, 298.1086375433098, 263.54535796475096, 236.70281884413203, 274.8913302752344, 429.4756414645605, 369.6765274074642, 363.69260124148775, 281.83251545803427, 288.94867047879933, 347.82463134556787, 438.7818497213343, 319.22038581515346, 1145.3853227374977, 1121.273626444329, 750.8684024160292, 678.8063501374403, 632.4233147506563, 592.030239784551, 590.2695308310107, 562.6400872885639, 594.721284500554, 464.98344324762485, 430.36989441585547, 416.9062232945961, 405.99521811848814, 487.6346199993118, 371.5816698539653, 481.71666481114045, 362.0146031218757, 366.1987758942216, 352.56630479703597, 360.00373632495354, 435.60178857586527, 298.20956986230067, 278.5781125488814, 278.01403 ...

# %%
import gensim
from gensim import corpora
from pprint import pprint

# %%
from gensim import corpora, models, similarities

# %%
lda = gensim.models.ldamodel.LdaModel

# %%
import pyLDAvis.gensim_models as gensimvis

# %%
##Find which articles were marked in which cluster

# Assigns the topics to the documents in corpus
lda_corpus = lda_model[corpus]

# %%
[doc for doc in lda_corpus]
# Out:
# [([(0, 0.25007012), (1, 0.25001583), (2, 0.25010133), (3, 0.2498127)],
#   [(0, [3]), (1, [0]), (2, [2]), (3, [1])],
#   [(0, [(3, 0.9984406)]),
#    (1, [(0, 0.9999315)]),
#    (2, [(2, 0.9996517)]),
#    (3, [(1, 0.999489)])]),
#  ([(0, 0.05485111), (1, 0.5652381), (2, 0.055430826), (3, 0.32448)],
#   [(4, [1, 3]), (5, [1]), (6, [1]), (7, [3])],
#   [(4, [(1, 0.32802734), (3, 0.24655575)]),
#    (5, [(1, 0.9998692)]),
#    (6, [(1, 0.9996262)]),
#    (7, [(3, 0.9867216)])]),
#  ([(0, 0.41664806), (1, 0.083336614), (2, 0.08333677), (3, 0.41667852)],
#   [(8, [0]), (9, [3])],
#   [(8, [(0, 0.99989194)]), (9, [(3, 0.9999435)])]),
#  ([(0, 0.10879087), (1, 0.3228455), (2, 0.26377022), (3, 0.3045934)],
#   [(10, [0, 2, 3, 1]),
#    (11, [3, 2, 1, 0]),
#    (12, [3, 2, 1, 0]),
#    (13, [3]),
#    (14, [1, 2, 3, 0]),
#    (15, [1]),
#    (16, [2]),
#    (17, [2]),
#    (18, [3, 2, 1, 0]),
#    (19, [2]),
#    (20, [3, 2, 1, 0]),
#    (21, [3, 1, 2]),
#    (22, [3, 0, 1]),
#    (23, [3, 2, 1, 0]),
#    (24, [1]),
#    (25, [1, 3]),
#    (26, [1]),
#    (27, [1]),
#    (28, [0]),
#    (29, [2]),
#    (30, [3, 2, 1, 0]),
#    (31, [1, 3, 2]),
#    (32, [3, 2, 1, 0]),
#    (33, [0, 3, 2, 1]),
#    (34, [3, 2, 1, 0])],
#   [(10,
#     [(0, 0.55235404), (1, 0.056024686), (2, 0.19402765), (3, 0.079978086)]),
#    (11, [(0, 0.01781582), (1, 0.17183587), (2, 0.19470973), (3, 0.2489966)]),
#    (12, [(0, 0.03563164), (1, 0.34367174), (2, 0.38941947), (3, 0.4979932)]),
#    (13, [(3, 0.9903106)]),
#    (14, [(0, 0.02130145), (1, 0.4229592), (2, 0.34299153), (3, 0.21223864)]),
#    (15, [(1, 0.9994865)]),
#    (16, [(2, 0.99971783)]),
#    (17, [(2, 0.99994344)]),
#    (18, [(0, 0.016540786), (1, 0.16318415), (2, 0.18149622), (3, 0.3029212)]),
#    (19, [(2, 0.9996381)]),
#    (20, [(0, 0.017815627), (1, 0.17184596), (2, 0.19470502), (3, 0.2490003)]),
#    (21, [(1, 0.18226299), (2, 0.081951566), (3, 1.7270337)]),
#    (22, [(0, 0.032495156), (1, 0.031416103), (3, 1.9315295)]),
#    (23, [(0, 0.017815627), (1, 0.17184596), (2, 0.19470502), (3, 0.2490003)]),
#    (24, [(1, 0.99935263)]),
#    (25, [(1, 0.9396324), (3, 0.041020527)]),
#    (26, [(1, 0.9996479)]),
#    (27, [(1, 0.9986207)]),
#    (28, [(0, 0.99807703)]),
#    (29, [(2, 0.9991099)]),
#    (30, [(0, 0.01781582), (1, 0.17183587), (2, 0.19470973), (3, 0.2489966)]),
#    (31, [(1, 0.86507255), (2, 0.0141679235), (3, 0.093616575)]),
#    (32, [(0, 0.01781582), (1, 0.17183587), (2, 0.19470973), (3, 0.2489966)]),
#    (33,
#     [(0, 0.85358673), (1, 0.022115389), (2, 0.038032506), (3, 0.041972168)]),
#    (34, [(0, 0.053447463), (1, 0.5155076), (2, 0.5841292), (3, 0.7469898)])]),
#  ([(0, 0.054324847), (1, 0.0546266), (2, 0.5736761), (3, 0.31737247)],
#   [(35, [3]), (36, [2]), (37, [2]), (38, [2, 3])],
#   [(35, [(3, 0.9973861)]),
#    (36, [(2, 0.99918777)]),
#    (37, [(2, 0.98260844)]),
#    (38, [(2, 0.41481924), (3, 0.21058843)])]),
#  ([(0, 0.25026503), (1, 0.24860439), (2, 0.24986051), (3, 0.2512701)],
#   [(9, [3]), (36, [2]), (39, [0]), (40, [1])],
#   [(9, [(3, 0.9998527)]),
#    (36, [(2, 0.99724746)]),
#    (39, [(0, 0.9998481)]),
#    (40, [(1, 0.9915394)])]),
#  ([(0, 0.040307317), (1, 0.2370343), (2, 0.4750502), (3, 0.24760817)],
#   [(2, [2]),
#    (3, [1]),
#    (41, [2, 3, 1]),
#    (42, [2, 3, 1]),
#    (43, [2]),
#    (44, [3, 2])],
#   [(2, [(2, 0.99986184)]),
#    (3, [(1, 0.99936944)]),
#    (41, [(1, 0.10193165), (2, 0.34946972), (3, 0.1670034)]),
#    (42, [(1, 0.12467894), (2, 0.35273924), (3, 0.16819696)]),
#    (43, [(2, 0.9967021)]),
#    (44, [(2, 0.019362804), (3, 0.959671)])]),
#  ([(0, 0.1250281), (1, 0.12503047), (2, 0.6249073), (3, 0.12503406)],
#   [(36, [2])],
#   [(36, [(2, 0.9995538)])]),
#  ([(0, 0.4627695), (1, 0.4712879), (2, 0.032967445), (3, 0.03297511)],
#   [(5, [1]),
#    (45, [1, 0]),
#    (46, [0]),
#    (47, [1]),
#    (48, [1, 0]),
#    (49, [0]),
#    (50, [0])],
#   [(5, [(1, 0.99987733)]),
#    (45, [(0, 0.23711602), (1, 0.6964085)]),
#    (46, [(0, 0.9991135)]),
#    (47, [(1, 0.99746096)]),
#    (48, [(0, 0.11812904), (1, 0.72093964)]),
#    (49, [(0, 0.9999324)]),
#    (50, [(0, 0.9954934)])]),
#  ([(0, 0.2837139), (1, 0.055281676), (2, 0.6054112), (3, 0.055593256)],
#   [(2, [2]), (36, [2]), (51, [2, 0]), (52, [0])],
#   [(2, [(2, 0.9999417)]),
#    (36, [(2, 0.99952507)]),
#    (51, [(0, 0.04683005), (2, 0.51439184)]),
#    (52, [(0, 0.998668)])]),
#  ([(0, 0.04264194), (1, 0.3934585), (2, 0.04272863), (3, 0.521171)],
#   [(3, [1]), (53, [3, 1]), (54, [1]), (55, [3]), (56, [3])],
#   [(3, [(1, 0.9995709)]),
#    (53, [(1, 0.06260182), (3, 0.8149196)]),
#    (54, [(1, 0.9930801)]),
#    (55, [(3, 0.99996465)]),
#    (56, [(3, 0.9887903)])]),
#  ([(0, 0.34789035), (1, 0.1144717), (2, 0.011588825), (3, 0.5260492)],
#   [(13, [3]),
#    (44, [3]),
#    (56, [3]),
#    (57, [3, 0]),
#    (58, [0]),
#    (59, [3]),
#    (60, [0, 1, 3]),
#    (61, [0]),
#    (62, [1]),
#    (63, [1]),
#    (64, [3, 0, 1]),
#    (65, [3]),
#    (66, [0]),
#    (67, [0]),
#    (68, [3]),
#    (69, [3]),
#    (70, [0]),
#    (71, [3, 0, 1]),
#    (72, [3])],
#   [(13, [(3, 0.9985064)]),
#    (44, [(3, 0.9917656)]),
#    (56, [(3, 0.9909625)]),
#    (57, [(0, 0.28030467), (3, 0.71964777)]),
#    (58, [(0, 0.9998499)]),
#    (59, [(3, 0.99986666)]),
#    (60, [(0, 0.8840793), (1, 0.09396408), (3, 0.013454041)]),
#    (61, [(0, 0.99982524)]),
#    (62, [(1, 0.99908817)]),
#    (63, [(1, 0.9975629)]),
#    (64, [(0, 0.06942402), (1, 0.056790397), (3, 0.47623855)]),
#    (65, [(3, 1.9999062)]),
#    (66, [(0, 1.999228)]),
#    (67, [(0, 0.9965698)]),
#    (68, [(3, 0.9999768)]),
#    (69, [(3, 0.9999854)]),
#    (70, [(0, 0.9985394)]),
#    (71, [(0, 0.124895535), (1, 0.10216529), (3, 1.0577627)]),
#    (72, [(3, 0.99775326)])]),
#  ([(0, 0.2870807), (1, 0.11910183), (2, 0.11401333), (3, 0.47980413)],
#   [(68, [3]),
#    (73, [3]),
#    (74, [0]),
#    (75, [0, 1]),
#    (76, [3]),
#    (77, [0, 3]),
#    (78, [1]),
#    (79, [3]),
#    (80, [3]),
#    (81, [2])],
#   [(68, [(3, 0.99997157)]),
#    (73, [(3, 0.99974483)]),
#    (74, [(0, 0.99887574)]),
#    (75, [(0, 0.9327574), (1, 0.058937922)]),
#    (76, [(3, 0.9999355)]),
#    (77, [(0, 0.97432005), (3, 0.018554175)]),
#    (78, [(1, 0.9994918)]),
#    (79, [(3, 0.9996536)]),
#    (80, [(3, 0.99990475)]),
#    (81, [(2, 0.9998338)])]),
#  ([(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)], [], []),
#  ([(0, 0.1645509), (1, 0.03287302), (2, 0.032940976), (3, 0.7696351)],
#   [(0, [3]),
#    (13, [3]),
#    (68, [3]),
#    (82, [0]),
#    (83, [3, 0]),
#    (84, [3]),
#    (85, [3])],
#   [(0, [(3, 0.99981195)]),
#    (13, [(3, 0.99931204)]),
#    (68, [(3, 0.99998754)]),
#    (82, [(0, 0.986156)]),
#    (83, [(0, 0.02092658), (3, 0.62213075)]),
#    (84, [(3, 0.99998504)]),
#    (85, [(3, 0.9998667)])]),
#  ([(0, 0.5822303), (1, 0.02788266), (2, 0.027980091), (3, 0.36190692)],
#   [(0, [3]),
#    (84, [3]),
#    (86, [0]),
#    (87, [0]),
#    (88, [0]),
#    (89, [0]),
#    (90, [0]),
#    (91, [3])],
#   [(0, [(3, 0.9994112)]),
#    (84, [(3, 0.99995416)]),
#    (86, [(0, 0.99886334)]),
#    (87, [(0, 0.9995709)]),
#    (88, [(0, 0.9826335)]),
#    (89, [(0, 0.99989414)]),
#    (90, [(0, 0.9998967)]),
#    (91, [(3, 0.994307)])]),
#  ([(0, 0.19407824), (1, 0.2086776), (2, 0.2279646), (3, 0.36927953)],
#   [(92, [3, 2, 1])],
#   [(92, [(1, 0.025868589), (2, 0.050875314), (3, 0.24072431)])]),
#  ([(0, 0.21418515), (1, 0.29352736), (2, 0.32491452), (3, 0.16737296)],
#   [(1, [0]),
#    (81, [2]),
#    (93, [2, 1, 0]),
#    (94, [2, 1, 3, 0]),
#    (95, [2, 1, 3, 0]),
#    (96, [2, 1, 3, 0]),
#    (97, [2, 1, 3, 0]),
#    (98, [0, 1]),
#    (99, [3, 2, 1]),
#    (100, [2, 1, 3, 0]),
#    (101, [1])],
#   [(1, [(0, 0.9999219)]),
#    (81, [(2, 0.99996567)]),
#    (93, [(0, 0.03001637), (1, 0.39669096), (2, 0.57059026)]),
#    (94, [(0, 0.038373046), (1, 0.16264588), (2, 0.25782055), (3, 0.12298623)]),
#    (95, [(0, 0.038373116), (1, 0.16264586), (2, 0.25782055), (3, 0.12298621)]),
#    (96, [(0, 0.038373046), (1, 0.16264588), (2, 0.25782055), (3, 0.12298623)]),
#    (97, [(0, 0.038373046), (1, 0.16264588), (2, 0.25782055), (3, 0.12298623)]),
#    (98, [(0, 0.6027983), (1, 0.39701983)]),
#    (99, [(1, 0.03968656), (2, 0.06260136), (3, 0.78719604)]),
#    (100, [(0, 0.06066489), (1, 0.15210211), (2, 0.28132853), (3, 0.11516887)]),
#    (101, [(1, 0.999812)])]),
#  ([(0, 0.04052879), (1, 0.14674546), (2, 0.114806056), (3, 0.6979197)],
#   [(43, [2, 3]),
#    (44, [3]),
#    (54, [1, 3]),
#    (55, [3]),
#    (56, [3]),
#    (68, [3]),
#    (76, [3]),
#    (79, [3]),
#    (81, [2]),
#    (85, [3]),
#    (102, [3, 2, 1, 0]),
#    (103, [3, 2, 1]),
#    (104, [3, 1]),
#    (105, [3]),
#    (106, [3, 1, 0, 2]),
#    (107, [1]),
#    (108, [3]),
#    (109, [3, 2, 1]),
#    (110, [1]),
#    (111, [3, 2]),
#    (112, [0]),
#    (113, [1]),
#    (114, [3, 2]),
#    (115, [2, 1, 3]),
#    (116, [3]),
#    (117, [3])],
#   [(43, [(2, 0.9695674), (3, 0.023381403)]),
#    (44, [(3, 1.9861565)]),
#    (54, [(1, 0.97453004), (3, 0.017103408)]),
#    (55, [(3, 3.9999077)]),
#    (56, [(3, 0.9927161)]),
#    (68, [(3, 0.9999814)]),
#    (76, [(3, 0.99995846)]),
#    (79, [(3, 0.99976933)]),
#    (81, [(2, 0.9998529)]),
#    (85, [(3, 0.9996997)]),
#    (102, [(0, 0.013945198), (1, 0.19905269), (2, 0.21216416), (3, 1.5901132)]),
#    (103, [(1, 0.04089275), (2, 0.26151177), (3, 0.6944318)]),
#    (104, [(1, 0.09078816), (3, 0.9091824)]),
#    (105, [(3, 0.9998908)]),
#    (106,
#     [(0, 0.057655156), (1, 0.081431545), (2, 0.049969528), (3, 0.80982363)]),
#    (107, [(1, 0.9972062)]),
#    (108, [(3, 0.9954928)]),
#    (109, [(1, 0.06635089), (2, 0.07072138), (3, 0.53003764)]),
#    (110, [(1, 0.9946854)]),
#    (111, [(2, 0.016110975), (3, 0.98330194)]),
#    (112, [(0, 0.9930538)]),
#    (113, [(1, 0.9921919)]),
#    (114, [(2, 0.025153596), (3, 1.9740059)]),
#    (115, [(1, 0.09355196), (2, 0.8813154), (3, 0.015335196)]),
#    (116, [(3, 0.9999734)]),
#    (117, [(3, 0.9997077)])]),
#  ([(0, 0.35764802), (1, 0.24039863), (2, 0.016335808), (3, 0.38561755)],
#   [(3, [1]),
#    (28, [0]),
#    (39, [0]),
#    (68, [3]),
#    (73, [3]),
#    (118, [3, 1, 0]),
#    (119, [3, 0]),
#    (120, [0]),
#    (121, [3]),
#    (122, [1]),
#    (123, [3, 1, 0]),
#    (124, [3, 1, 0]),
#    (125, [0]),
#    (126, [1]),
#    (127, [3, 1, 0]),
#    (128, [0])],
#   [(3, [(1, 0.9994203)]),
#    (28, [(0, 0.99958676)]),
#    (39, [(0, 0.99991405)]),
#    (68, [(3, 0.99996245)]),
#    (73, [(3, 0.99967337)]),
#    (118, [(0, 0.07506817), (1, 0.13842928), (3, 0.36130092)]),
#    (119, [(0, 0.034946688), (3, 0.9614059)]),
#    (120, [(0, 0.9984665)]),
#    (121, [(3, 0.9897838)]),
#    (122, [(1, 0.9997018)]),
#    (123, [(0, 0.07506817), (1, 0.13842928), (3, 0.36130092)]),
#    (124, [(0, 0.07506817), (1, 0.13842928), (3, 0.36130092)]),
#    (125, [(0, 0.9988234)]),
#    (126, [(1, 0.9884922)]),
#    (127, [(0, 0.036602024), (1, 0.07310883), (3, 0.69015926)]),
#    (128, [(0, 0.9992336)])]),
#  ([(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)], [], []),
#  ([(0, 0.66600585), (1, 0.036944434), (2, 0.037218325), (3, 0.25983134)],
#   [(129, [0, 3]),
#    (130, [0]),
#    (131, [0]),
#    (132, [3]),
#    (133, [0]),
#    (134, [3, 0]),
#    (135, [3, 0])],
#   [(129, [(0, 0.96382606), (3, 0.011738468)]),
#    (130, [(0, 0.9996041)]),
#    (131, [(0, 0.9992275)]),
#    (132, [(3, 0.9993399)]),
#    (133, [(0, 0.99996996)]),
#    (134, [(0, 0.18434617), (3, 0.26313096)]),
#    (135, [(0, 0.18434617), (3, 0.26313096)])]),
#  ([(0, 0.27108473), (1, 0.12946989), (2, 0.36369675), (3, 0.23574865)],
#   [(134, [2, 3, 1, 0]),
#    (136, [3, 0]),
#    (137, [0, 2, 3, 1]),
#    (138, [2]),
#    (139, [2]),
#    (140, [3]),
#    (141, [1]),
#    (142, [2]),
#    (143, [0]),
#    (144, [0])],
#   [(134, [(0, 0.05098314), (1, 0.055635095), (2, 0.2908005), (3, 0.19070578)]),
#    (136, [(0, 0.1426178), (3, 0.85711175)]),
#    (137, [(0, 0.34790376), (1, 0.03825972), (2, 0.20019005), (3, 0.13093081)]),
#    (138, [(2, 0.99886906)]),
#    (139, [(2, 0.9994505)]),
#    (140, [(3, 0.99500304)]),
#    (141, [(1, 0.988368)]),
#    (142, [(2, 0.9993632)]),
#    (143, [(0, 0.9993675)]),
#    (144, [(0, 0.99935037)])]),
#  ([(0, 0.28764296), (1, 0.21468401), (2, 0.47584125), (3, 0.02183178)],
#   [(96, [2, 1, 0]),
#    (129, [0, 2, 1]),
#    (133, [0]),
#    (134, [2, 1, 0]),
#    (138, [2]),
#    (142, [2]),
#    (145, [1, 2]),
#    (146, [0]),
#    (147, [1, 0])],
#   [(96, [(0, 0.0568561), (1, 0.11534832), (2, 0.405238)]),
#    (129, [(0, 0.8759193), (1, 0.015112694), (2, 0.05390824)]),
#    (133, [(0, 0.99987924)]),
#    (134, [(0, 0.1137122), (1, 0.23069663), (2, 0.810476)]),
#    (138, [(2, 1.998616)]),
#    (142, [(2, 1.9992307)]),
#    (145, [(1, 0.942006), (2, 0.03017154)]),
#    (146, [(0, 0.99966997)]),
#    (147, [(0, 0.050519552), (1, 0.9491097)])]),
#  ([(0, 0.50063753), (1, 0.19445106), (2, 0.113017075), (3, 0.19189435)],
#   [(1, [0]),
#    (67, [0]),
#    (96, [3, 0, 1, 2]),
#    (135, [3, 0, 1, 2]),
#    (136, [3, 0]),
#    (138, [2]),
#    (141, [1]),
#    (148, [1]),
#    (149, [3, 0, 1, 2]),
#    (150, [0]),
#    (151, [0]),
#    (152, [3]),
#    (153, [3, 0, 1, 2]),
#    (154, [0]),
#    (155, [0])],
#   [(1, [(0, 0.9999784)]),
#    (67, [(0, 0.9981108)]),
#    (96, [(0, 0.12302575), (1, 0.1217335), (2, 0.085369654), (3, 0.18466881)]),
#    (135, [(0, 0.12302575), (1, 0.1217335), (2, 0.085369654), (3, 0.18466881)]),
#    (136, [(0, 0.2930446), (3, 0.70673674)]),
#    (138, [(2, 0.9948946)]),
#    (141, [(1, 0.9950673)]),
#    (148, [(1, 0.99835587)]),
#    (149, [(0, 0.12302575), (1, 0.1217335), (2, 0.085369654), (3, 0.18466881)]),
#    (150, [(0, 0.9999428)]),
#    (151, [(0, 0.9992478)]),
#    (152, [(3, 0.996943)]),
#    (153, [(0, 0.12302575), (1, 0.1217335), (2, 0.085369654), (3, 0.18466881)]),
#    (154, [(0, 0.9995879)]),
#    (155, [(0, 0.9999047)])]),
#  ([(0, 0.64802724), (1, 0.11518304), (2, 0.11786203), (3, 0.118927635)],
#   [(155, [0]), (156, [0, 3, 2, 1])],
#   [(155, [(0, 0.999957)]),
#    (156,
#     [(0, 0.21802616), (1, 0.01085276), (2, 0.016764682), (3, 0.01908388)])]),
#  ([(0, 0.3069843), (1, 0.48103625), (2, 0.17873123), (3, 0.033248216)],
#   [(112, [0]),
#    (157, [1, 2, 0]),
#    (158, [1]),
#    (159, [2]),
#    (160, [0]),
#    (161, [1, 0, 2]),
#    (162, [1])],
#   [(112, [(0, 0.9995104)]),
#    (157, [(0, 0.054796547), (1, 0.44257715), (2, 0.106485255)]),
#    (158, [(1, 0.9983807)]),
#    (159, [(2, 0.98274183)]),
#    (160, [(0, 0.9980043)]),
#    (161, [(0, 0.027479082), (1, 0.95446044), (2, 0.016727496)]),
#    (162, [(1, 0.9995291)])]),
#  ([(0, 0.8496301), (1, 0.11997535), (2, 0.015153845), (3, 0.015240671)],
#   [(1, [0]),
#    (163, [0]),
#    (164, [0]),
#    (165, [1, 0]),
#    (166, [1, 0]),
#    (167, [0]),
#    (168, [0]),
#    (169, [0]),
#    (170, [0]),
#    (171, [0]),
#    (172, [0]),
#    (173, [0]),
#    (174, [0, 1]),
#    (175, [0]),
#    (176, [0, 1]),
#    (177, [0]),
#    (178, [0, 1])],
#   [(1, [(0, 0.99999297)]),
#    (163, [(0, 0.99995106)]),
#    (164, [(0, 0.9994763)]),
#    (165, [(0, 0.029930742), (1, 0.91434944)]),
#    (166, [(0, 0.48739946), (1, 0.50012404)]),
#    (167, [(0, 0.99994576)]),
#    (168, [(0, 0.99974)]),
#    (169, [(0, 0.9995576)]),
#    (170, [(0, 0.99997544)]),
#    (171, [(0, 0.99922466)]),
#    (172, [(0, 0.9999901)]),
#    (173, [(0, 0.9999743)]),
#    (174, [(0, 0.8444266), (1, 0.1554742)]),
#    (175, [(0, 0.9997805)]),
#    (176, [(0, 0.27909404), (1, 0.08964515)]),
#    (177, [(0, 0.9998716)]),
#    (178, [(0, 0.27909404), (1, 0.08964515)])]),
#  ([(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)], [], []),
#  ([(0, 0.89569074), (2, 0.08933317)],
#   [(39, [0]),
#    (98, [0]),
#    (133, [0]),
#    (137, [0, 2]),
#    (154, [0]),
#    (168, [0]),
#    (173, [0]),
#    (179, [0, 2]),
#    (180, [0, 2]),
#    (181, [0]),
#    (182, [0]),
#    (183, [0]),
#    (184, [0]),
#    (185, [0]),
#    (186, [0]),
#    (187, [0]),
#    (188, [0]),
#    (189, [2]),
#    (190, [0, 2]),
#    (191, [2]),
#    (192, [0]),
#    (193, [0]),
#    (194, [0]),
#    (195, [0]),
#    (196, [0]),
#    (197, [0, 2]),
#    (198, [0]),
#    (199, [0, 2]),
#    (200, [0, 2]),
#    (201, [0, 2]),
#    (202, [0]),
#    (203, [0]),
#    (204, [0]),
#    (205, [0])],
#   [(39, [(0, 0.9999845)]),
#    (98, [(0, 0.9997328)]),
#    (133, [(0, 1.9999677)]),
#    (137, [(0, 0.8004665), (2, 0.027835649)]),
#    (154, [(0, 0.999876)]),
#    (168, [(0, 0.9997468)]),
#    (173, [(0, 0.99997497)]),
#    (179, [(0, 0.2877583), (2, 0.09918831)]),
#    (180, [(0, 0.28759545), (2, 0.09913464)]),
#    (181, [(0, 0.9999585)]),
#    (182, [(0, 1.9995456)]),
#    (183, [(0, 0.9998875)]),
#    (184, [(0, 0.9995295)]),
#    (185, [(0, 0.99936366)]),
#    (186, [(0, 0.9999894)]),
#    (187, [(0, 0.9994821)]),
#    (188, [(0, 0.9998502)]),
#    (189, [(2, 0.9988181)]),
#    (190, [(0, 0.28759545), (2, 0.09913464)]),
#    (191, [(2, 0.98942983)]),
#    (192, [(0, 0.99912775)]),
#    (193, [(0, 0.99974895)]),
#    (194, [(0, 0.9981693)]),
#    (195, [(0, 1.9996365)]),
#    (196, [(0, 0.99995583)]),
#    (197, [(0, 0.4292534), (2, 0.07994955)]),
#    (198, [(0, 0.98549044)]),
#    (199, [(0, 0.59239644), (2, 0.19591525)]),
#    (200, [(0, 0.28759545), (2, 0.09913464)]),
#    (201, [(0, 0.28759545), (2, 0.09913464)]),
#    (202, [(0, 0.99733186)]),
#    (203, [(0, 0.9999772)]),
#    (204, [(0, 0.9999727)]),
#    (205, [(0, 0.99977815)])]),
#  ([(0, 0.4351827), (1, 0.17511421), (2, 0.1079047), (3, 0.28179836)],
#   [(69, [3]),
#    (172, [0]),
#    (206, [3, 1, 0, 2]),
#    (207, [1]),
#    (208, [3, 1, 0, 2]),
#    (209, [3, 0, 1, 2]),
#    (210, [0]),
#    (211, [2]),
#    (212, [3]),
#    (213, [0]),
#    (214, [0]),
#    (215, [1, 0]),
#    (216, [0])],
#   [(69, [(3, 0.9999637)]),
#    (172, [(0, 0.99995774)]),
#    (206,
#     [(0, 0.09927533), (1, 0.09944849), (2, 0.073301144), (3, 0.27064133)]),
#    (207, [(1, 0.9985512)]),
#    (208,
#     [(0, 0.09927533), (1, 0.09944849), (2, 0.073301144), (3, 0.27064133)]),
#    (209,
#     [(0, 0.023401879), (1, 0.019354515), (2, 0.012611575), (3, 0.8760419)]),
#    (210, [(0, 0.99950445)]),
#    (211, [(2, 0.99341565)]),
#    (212, [(3, 0.9931383)]),
#    (213, [(0, 0.9996893)]),
#    (214, [(0, 0.99875814)]),
#    (215, [(0, 0.19034827), (1, 0.8094651)]),
#    (216, [(0, 0.9994519)])]),
#  ([(0, 0.21187729), (1, 0.30066562), (2, 0.10325113), (3, 0.384206)],
#   [(73, [3]),
#    (98, [0, 1]),
#    (110, [1]),
#    (150, [0]),
#    (217, [1]),
#    (218, [3, 1, 2, 0]),
#    (219, [3, 1, 2, 0]),
#    (220, [1]),
#    (221, [3, 1, 2, 0]),
#    (222, [0, 3]),
#    (223, [2]),
#    (224, [3]),
#    (225, [3])],
#   [(73, [(3, 0.9996236)]),
#    (98, [(0, 0.598603), (1, 0.40121782)]),
#    (110, [(1, 0.998271)]),
#    (150, [(0, 0.9997949)]),
#    (217, [(1, 0.9997786)]),
#    (218,
#     [(0, 0.038428556), (1, 0.16575705), (2, 0.06139475), (3, 0.33578062)]),
#    (219,
#     [(0, 0.038428556), (1, 0.16575705), (2, 0.06139475), (3, 0.33578062)]),
#    (220, [(1, 0.9998661)]),
#    (221,
#     [(0, 0.03885133), (1, 0.16620784), (2, 0.061874334), (3, 0.33801484)]),
#    (222, [(0, 0.9580083), (3, 0.0389794)]),
#    (223, [(2, 0.98959863)]),
#    (224, [(3, 0.99973834)]),
#    (225, [(3, 1.9998622)])]),
#  ([(0, 0.096556135), (1, 0.09769787), (2, 0.09848599), (3, 0.70725995)],
#   [(226, [3]), (227, [3])],
#   [(226, [(3, 0.5932086)]), (227, [(3, 0.9989578)])]),
#  ([(0, 0.710088), (1, 0.10135003), (2, 0.083717495), (3, 0.10484444)],
#   [(228, [0, 3, 1]), (229, [0])],
#   [(228, [(0, 0.87965167), (1, 0.053168774), (3, 0.06327118)]),
#    (229, [(0, 0.99888164)])]),
#  ([(0, 0.6546196), (1, 0.3171825), (2, 0.0141381575), (3, 0.014059726)],
#   [(46, [0]),
#    (62, [1]),
#    (155, [0]),
#    (195, [0]),
#    (230, [0]),
#    (231, [0]),
#    (232, [1]),
#    (233, [1, 0]),
#    (234, [0]),
#    (235, [1, 0]),
#    (236, [0]),
#    (237, [1]),
#    (238, [0, 1]),
#    (239, [0]),
#    (240, [1, 0]),
#    (241, [0]),
#    (242, [1, 0]),
#    (243, [1]),
#    (244, [0, 1]),
#    (245, [1, 0])],
#   [(46, [(0, 0.99950165)]),
#    (62, [(1, 0.99983805)]),
#    (155, [(0, 0.9999464)]),
#    (195, [(0, 0.999673)]),
#    (230, [(0, 0.9999528)]),
#    (231, [(0, 0.9978848)]),
#    (232, [(1, 0.9999449)]),
#    (233, [(0, 0.18892723), (1, 0.2513023)]),
#    (234, [(0, 0.99978095)]),
#    (235, [(0, 0.18925908), (1, 0.25635839)]),
#    (236, [(0, 0.9934014)]),
#    (237, [(1, 0.9955445)]),
#    (238, [(0, 0.84584224), (1, 0.15162121)]),
#    (239, [(0, 0.99952364)]),
#    (240, [(0, 0.18892723), (1, 0.2513023)]),
#    (241, [(0, 0.99765354)]),
#    (242, [(0, 0.18892723), (1, 0.2513023)]),
#    (243, [(1, 0.99979854)]),
#    (244, [(0, 0.8881075), (1, 0.10733919)]),
#    (245, [(0, 0.18892723), (1, 0.2513023)])]),
#  ([(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)], [], []),
#  ([(0, 0.81232595), (1, 0.0625227), (2, 0.0625193), (3, 0.06263204)],
#   [(70, [0]), (246, [0]), (247, [0])],
#   [(70, [(0, 0.9997402)]), (246, [(0, 0.99988717)]), (247, [(0, 0.998995)])]),
#  ([(0, 0.37833157), (1, 0.027442884), (2, 0.19770876), (3, 0.3965168)],
#   [(73, [3]),
#    (223, [2]),
#    (248, [3, 2]),
#    (249, [0, 3]),
#    (250, [3, 2, 0]),
#    (251, [0]),
#    (252, [3, 2, 0]),
#    (253, [3, 2, 0]),
#    (254, [0]),
#    (255, [3, 2, 0])],
#   [(73, [(3, 0.9996419)]),
#    (223, [(2, 0.99524)]),
#    (248, [(2, 0.02145131), (3, 0.97043836)]),
#    (249, [(0, 0.95141184), (3, 0.02309797)]),
#    (250, [(0, 0.07665592), (2, 0.13975127), (3, 0.35870728)]),
#    (251, [(0, 0.99902827)]),
#    (252, [(0, 0.07665592), (2, 0.13975127), (3, 0.35870728)]),
#    (253, [(0, 0.076698504), (2, 0.13993566), (3, 0.35871738)]),
#    (254, [(0, 0.99567515)]),
#    (255, [(0, 0.07665592), (2, 0.13975127), (3, 0.35870728)])]),
#  ([(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)], [], []),
#  ([(0, 0.24368462), (1, 0.10101281), (2, 0.07628822), (3, 0.57901436)],
#   [(39, [0]),
#    (56, [3]),
#    (58, [0]),
#    (101, [1]),
#    (132, [3]),
#    (224, [3]),
#    (250, [3, 0, 1, 2]),
#    (252, [3, 0, 1, 2]),
#    (255, [3, 0, 1, 2]),
#    (256, [3, 0, 1, 2]),
#    (257, [3]),
#    (258, [3]),
#    (259, [3, 0, 1, 2]),
#    (260, [2, 3, 0]),
#    (261, [0]),
#    (262, [3, 0, 1, 2])],
#   [(39, [(0, 0.99984676)]),
#    (56, [(3, 0.9917275)]),
#    (58, [(0, 0.99975204)]),
#    (101, [(1, 0.9991726)]),
#    (132, [(3, 0.99976796)]),
#    (224, [(3, 0.99986666)]),
#    (250,
#     [(0, 0.04341013), (1, 0.041302823), (2, 0.038347866), (3, 0.49812275)]),
#    (252,
#     [(0, 0.04341013), (1, 0.041302823), (2, 0.038347866), (3, 0.49812275)]),
#    (255,
#     [(0, 0.04341013), (1, 0.041302823), (2, 0.038347866), (3, 0.49812275)]),
#    (256,
#     [(0, 0.04600393), (1, 0.041192446), (2, 0.038256474), (3, 0.4969034)]),
#    (257, [(3, 0.9988545)]),
#    (258, [(3, 0.9996545)]),
#    (259,
#     [(0, 0.043410525), (1, 0.041302804), (2, 0.038347848), (3, 0.49812254)]),
#    (260, [(0, 0.092534155), (2, 0.65875715), (3, 0.17895098)]),
#    (261, [(0, 0.9994433)]),
#    (262,
#     [(0, 0.041348536), (1, 0.027524732), (2, 0.025564775), (3, 0.6537047)])]),
#  ([(0, 0.4204717), (1, 0.0455943), (2, 0.48806226), (3, 0.045871776)],
#   [(199, [2, 0]), (263, [2]), (264, [0]), (265, [2]), (266, [0, 2])],
#   [(199, [(0, 0.09351108), (2, 0.43542403)]),
#    (263, [(2, 0.9999862)]),
#    (264, [(0, 0.99978566)]),
#    (265, [(2, 0.9999636)]),
#    (266, [(0, 0.98295784), (2, 0.01478657)])]),
#  ([(0, 0.6479305), (1, 0.1152077), (2, 0.117898464), (3, 0.11896332)],
#   [(1, [0]), (267, [0, 3, 2, 1])],
#   [(1, [(0, 0.9999903)]),
#    (267,
#     [(0, 0.21749392), (1, 0.010863374), (2, 0.016787432), (3, 0.019089203)])]),
#  ([(0, 0.19412562), (1, 0.20875041), (2, 0.22812422), (3, 0.36899972)],
#   [(268, [3, 2, 1])],
#   [(268, [(1, 0.025899958), (2, 0.051000554), (3, 0.24030352)])]),
#  ([(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)], [], []),
#  ([(0, 0.29968402), (1, 0.054994423), (2, 0.58918446), (3, 0.056137126)],
#   [(1, [0]), (269, [2, 0]), (270, [2, 0]), (271, [2, 0]), (272, [2])],
#   [(1, [(0, 0.9999424)]),
#    (269, [(0, 0.051707026), (2, 0.5042464)]),
#    (270, [(0, 0.051707026), (2, 0.5042464)]),
#    (271, [(0, 0.051707026), (2, 0.5042464)]),
#    (272, [(2, 0.9999686)])]),
#  ([(0, 0.4493882), (1, 0.050033033), (2, 0.0500347), (3, 0.45054403)],
#   [(76, [3]), (150, [0]), (241, [0]), (273, [3])],
#   [(76, [(3, 0.9999372)]),
#    (150, [(0, 0.99992484)]),
#    (241, [(0, 0.9948362)]),
#    (273, [(3, 0.99893063)])]),
#  ([(0, 0.8219156), (1, 0.023959527), (2, 0.1300983), (3, 0.024026547)],
#   [(100, [0, 2]),
#    (146, [0]),
#    (150, [0]),
#    (241, [0]),
#    (274, [0]),
#    (275, [0]),
#    (276, [0]),
#    (277, [0]),
#    (278, [2]),
#    (279, [0])],
#   [(100, [(0, 0.370031), (2, 0.11514359)]),
#    (146, [(0, 0.99996096)]),
#    (150, [(0, 0.9999784)]),
#    (241, [(0, 0.998465)]),
#    (274, [(0, 0.9995887)]),
#    (275, [(0, 0.99979454)]),
#    (276, [(0, 0.99940157)]),
#    (277, [(0, 0.9982575)]),
#    (278, [(2, 0.99756986)]),
#    (279, [(0, 0.9996989)])]),
#  ([(0, 0.40087798), (1, 0.4816342), (2, 0.05946649), (3, 0.058021363)],
#   [(280, [0, 1]), (281, [1, 0]), (282, [0, 1]), (283, [1]), (284, [1, 0])],
#   [(280, [(0, 0.95899266), (1, 0.03994353)]),
#    (281, [(0, 0.10259195), (1, 0.34535238)]),
#    (282, [(0, 0.4258097), (1, 0.219759)]),
#    (283, [(1, 0.9997921)]),
#    (284, [(0, 0.095508784), (1, 0.3479925)])]),
#  ([(0, 0.32207435), (1, 0.6063681), (2, 0.035778414), (3, 0.035779096)],
#   [(165, [1]), (285, [0]), (286, [0]), (287, [1]), (288, [1])],
#   [(165, [(1, 0.9883839)]),
#    (285, [(0, 0.9996993)]),
#    (286, [(0, 0.99915713)]),
#    (287, [(1, 0.99986106)]),
#    (288, [(1, 1.9990127)])]),
#  ([(0, 0.4812573), (1, 0.02404941), (2, 0.4640166), (3, 0.030676669)],
#   [(58, [0]),
#    (100, [2, 0]),
#    (150, [0]),
#    (289, [0, 2, 3]),
#    (290, [2]),
#    (291, [2]),
#    (292, [0, 2, 1]),
#    (293, [2]),
#    (294, [2, 0]),
#    (295, [2, 0]),
#    (296, [0])],
#   [(58, [(0, 0.99990386)]),
#    (100, [(0, 0.16201769), (2, 0.4342929)]),
#    (150, [(0, 0.99993336)]),
#    (289, [(0, 0.58583885), (2, 0.33822995), (3, 0.070520535)]),
#    (290, [(2, 0.9999801)]),
#    (291, [(2, 0.99994546)]),
#    (292, [(0, 0.79288626), (1, 0.010677602), (2, 0.09907448)]),
#    (293, [(2, 0.99998415)]),
#    (294, [(0, 0.10989962), (2, 0.42680687)]),
#    (295, [(0, 0.40271682), (2, 0.56410784)]),
#    (296, [(0, 0.99974036)])]),
#  ([(0, 0.3690956), (1, 0.25183243), (2, 0.08324397), (3, 0.295828)],
#   [(61, [0]),
#    (148, [1]),
#    (220, [1]),
#    (227, [3]),
#    (232, [1]),
#    (248, [3, 2, 0]),
#    (297, [0]),
#    (298, [3]),
#    (299, [0]),
#    (300, [1]),
#    (301, [0]),
#    (302, [3]),
#    (303, [2, 0, 3]),
#    (304, [3, 1, 0, 2]),
#    (305, [3]),
#    (306, [0]),
#    (307, [0]),
#    (308, [3, 1, 0, 2]),
#    (309, [3]),
#    (310, [2, 3]),
#    (311, [3, 1, 0, 2]),
#    (312, [0]),
#    (313, [0]),
#    (314, [3, 0])],
#   [(61, [(0, 0.9998453)]),
#    (148, [(1, 2.9957197)]),
#    (220, [(1, 0.9998518)]),
#    (227, [(3, 0.9960361)]),
#    (232, [(1, 0.99990565)]),
#    (248, [(0, 0.0100170635), (2, 0.011915609), (3, 0.9768386)]),
#    (297, [(0, 0.9984038)]),
#    (298, [(3, 0.9998187)]),
#    (299, [(0, 1.9924269)]),
#    (300, [(1, 0.9970391)]),
#    (301, [(0, 0.9998248)]),
#    (302, [(3, 0.9993015)]),
#    (303, [(0, 0.13970083), (2, 0.82767755), (3, 0.02239959)]),
#    (304, [(0, 0.079975404), (1, 0.15311864), (2, 0.0603007), (3, 0.28047824)]),
#    (305, [(3, 0.9995141)]),
#    (306, [(0, 0.9986059)]),
#    (307, [(0, 0.99971676)]),
#    (308, [(0, 0.079975404), (1, 0.15311864), (2, 0.0603007), (3, 0.28047824)]),
#    (309, [(3, 0.9997266)]),
#    (310, [(2, 0.94863427), (3, 0.01572917)]),
#    (311, [(0, 0.079975404), (1, 0.15311864), (2, 0.0603007), (3, 0.28047824)]),
#    (312, [(0, 0.9998876)]),
#    (313, [(0, 0.9999437)]),
#    (314, [(0, 0.21381044), (3, 0.78613)])]),
#  ([(0, 0.67363024), (1, 0.13405237), (2, 0.13892095), (3, 0.05339642)],
#   [(17, [2]),
#    (70, [0]),
#    (78, [1]),
#    (89, [0]),
#    (110, [1]),
#    (119, [3, 0, 2]),
#    (144, [0]),
#    (155, [0]),
#    (204, [0]),
#    (216, [0]),
#    (230, [0]),
#    (263, [2]),
#    (296, [0]),
#    (301, [0]),
#    (315, [0]),
#    (316, [0]),
#    (317, [0, 2, 1, 3]),
#    (318, [0]),
#    (319, [0, 1, 2]),
#    (320, [2, 0, 3, 1]),
#    (321, [0, 2, 1, 3]),
#    (322, [0, 2, 1, 3]),
#    (323, [0, 2, 1, 3]),
#    (324, [0]),
#    (325, [0, 2]),
#    (326, [0, 2, 1, 3]),
#    (327, [0]),
#    (328, [0, 2, 1, 3]),
#    (329, [0, 2, 1, 3]),
#    (330, [0]),
#    (331, [0, 2, 1, 3]),
#    (332, [1, 0, 2, 3]),
#    (333, [0]),
#    (334, [0]),
#    (335, [0]),
#    (336, [1, 2, 0]),
#    (337, [0]),
#    (338, [0, 1]),
#    (339, [3]),
#    (340, [2]),
#    (341, [0])],
#   [(17, [(2, 0.99991024)]),
#    (70, [(0, 0.99952614)]),
#    (78, [(1, 0.9997305)]),
#    (89, [(0, 0.9999343)]),
#    (110, [(1, 0.9973234)]),
#    (119, [(0, 0.3315297), (2, 0.12223497), (3, 0.5316575)]),
#    (144, [(0, 0.9998524)]),
#    (155, [(0, 0.9999406)]),
#    (204, [(0, 0.9999493)]),
#    (216, [(0, 0.9997489)]),
#    (230, [(0, 0.99995065)]),
#    (263, [(2, 0.9999263)]),
#    (296, [(0, 0.99986434)]),
#    (301, [(0, 0.9999333)]),
#    (315, [(0, 0.9974576)]),
#    (316, [(0, 0.9943376)]),
#    (317,
#     [(0, 0.18802686), (1, 0.09740031), (2, 0.14460057), (3, 0.051213127)]),
#    (318, [(0, 0.99985605)]),
#    (319, [(0, 0.8231812), (1, 0.060074747), (2, 0.02369278)]),
#    (320,
#     [(0, 0.40710264), (1, 0.042227093), (2, 0.49675837), (3, 0.04932195)]),
#    (321,
#     [(0, 0.47752792), (1, 0.11018974), (2, 0.39368623), (3, 0.015891472)]),
#    (322,
#     [(0, 0.18416494), (1, 0.097802036), (2, 0.14295642), (3, 0.05166858)]),
#    (323,
#     [(0, 0.5268852), (1, 0.05933592), (2, 0.110580474), (3, 0.044553444)]),
#    (324, [(0, 0.99963635)]),
#    (325, [(0, 0.9174356), (2, 0.0754938)]),
#    (326, [(0, 0.42265266), (1, 0.17976163), (2, 0.3406223), (3, 0.0949755)]),
#    (327, [(0, 0.9994842)]),
#    (328, [(0, 0.3872982), (1, 0.17926857), (2, 0.2634501), (3, 0.021793509)]),
#    (329, [(0, 0.18416439), (1, 0.0978023), (2, 0.14295515), (3, 0.05166872)]),
#    (330, [(0, 0.99986386)]),
#    (331, [(0, 0.18416439), (1, 0.0978023), (2, 0.14295515), (3, 0.05166872)]),
#    (332,
#     [(0, 0.034658026), (1, 0.9373932), (2, 0.012712435), (3, 0.010648784)]),
#    (333, [(0, 0.9995426)]),
#    (334, [(0, 0.9996719)]),
#    (335, [(0, 2.9985166)]),
#    (336, [(0, 0.021183902), (1, 0.85848653), (2, 0.064258374)]),
#    (337, [(0, 0.9998843)]),
#    (338, [(0, 0.52173746), (1, 0.47113997)]),
#    (339, [(3, 0.96680564)]),
#    (340, [(2, 0.99981636)]),
#    (341, [(0, 0.9989111)])]),
#  ([(0, 0.6787655), (1, 0.08343923), (2, 0.19479187), (3, 0.04300342)],
#   [(58, [0]),
#    (133, [0]),
#    (151, [0]),
#    (155, [0]),
#    (317, [2, 0, 1, 3]),
#    (326, [2, 0, 1, 3]),
#    (337, [0]),
#    (342, [3, 1]),
#    (343, [0]),
#    (344, [2, 1, 0, 3]),
#    (345, [2, 0, 1, 3]),
#    (346, [2]),
#    (347, [0, 2]),
#    (348, [2]),
#    (349, [0]),
#    (350, [1]),
#    (351, [0]),
#    (352, [0, 1]),
#    (353, [0]),
#    (354, [0]),
#    (355, [2]),
#    (356, [0]),
#    (357, [0])],
#   [(58, [(0, 0.9999503)]),
#    (133, [(0, 0.9999701)]),
#    (151, [(0, 1.9990911)]),
#    (155, [(0, 0.9999404)]),
#    (317,
#     [(0, 0.19090956), (1, 0.051524725), (2, 0.20222929), (3, 0.030327728)]),
#    (326,
#     [(0, 0.21135165), (1, 0.046834577), (2, 0.23461802), (3, 0.027700298)]),
#    (337, [(0, 0.9998843)]),
#    (342, [(1, 0.3674324), (3, 0.6309264)]),
#    (343, [(0, 0.9999518)]),
#    (344,
#     [(0, 0.15424995), (1, 0.17725049), (2, 0.62253356), (3, 0.032632552)]),
#    (345,
#     [(0, 0.18748043), (1, 0.05190801), (2, 0.20085432), (3, 0.030569272)]),
#    (346, [(2, 0.99933016)]),
#    (347, [(0, 0.947032), (2, 0.048865996)]),
#    (348, [(2, 0.9996169)]),
#    (349, [(0, 0.999573)]),
#    (350, [(1, 0.999497)]),
#    (351, [(0, 0.99922436)]),
#    (352, [(0, 0.9746293), (1, 0.012454173)]),
#    (353, [(0, 0.9998754)]),
#    (354, [(0, 0.99953073)]),
#    (355, [(2, 0.99945915)]),
#    (356, [(0, 0.99987876)]),
#    (357, [(0, 0.9994294)])]),
#  ([(0, 0.19108535), (1, 0.107247725), (2, 0.07628337), (3, 0.62538356)],
#   [(1, [0]),
#    (9, [3]),
#    (15, [1]),
#    (53, [3, 1, 2]),
#    (66, [0]),
#    (68, [3]),
#    (69, [3]),
#    (73, [3]),
#    (203, [0]),
#    (215, [1, 0]),
#    (341, [0]),
#    (358, [3]),
#    (359, [3, 1, 2, 0]),
#    (360, [3, 1, 2, 0]),
#    (361, [3]),
#    (362, [3, 1, 2, 0]),
#    (363, [2, 1]),
#    (364, [3, 2, 1]),
#    (365, [3, 1]),
#    (366, [3]),
#    (367, [3, 1, 2, 0]),
#    (368, [3]),
#    (369, [3, 1, 2, 0]),
#    (370, [3, 1, 2, 0])],
#   [(1, [(0, 0.999904)]),
#    (9, [(3, 0.9999672)]),
#    (15, [(1, 0.9981204)]),
#    (53, [(1, 0.013467829), (2, 0.0122935735), (3, 0.8649818)]),
#    (66, [(0, 0.9991397)]),
#    (68, [(3, 0.9999802)]),
#    (69, [(3, 1.999975)]),
#    (73, [(3, 0.99982417)]),
#    (203, [(0, 0.9997008)]),
#    (215, [(0, 0.13810188), (1, 0.86141306)]),
#    (341, [(0, 0.99237627)]),
#    (358, [(3, 0.9998304)]),
#    (359, [(0, 0.03284696), (1, 0.04826305), (2, 0.044059847), (3, 0.5160351)]),
#    (360, [(0, 0.03284696), (1, 0.04826305), (2, 0.044059847), (3, 0.5160351)]),
#    (361, [(3, 0.9998666)]),
#    (362, [(0, 0.03284696), (1, 0.04826305), (2, 0.044059847), (3, 0.5160351)]),
#    (363, [(1, 0.011907388), (2, 0.97937644)]),
#    (364, [(1, 0.015068276), (2, 0.32014832), (3, 0.66284555)]),
#    (365, [(1, 0.11298859), (3, 0.88684845)]),
#    (366, [(3, 0.9972635)]),
#    (367, [(0, 0.032644503), (1, 0.04765107), (2, 0.043780424), (3, 0.523511)]),
#    (368, [(3, 0.99993193)]),
#    (369,
#     [(0, 0.018571218), (1, 0.02731723), (2, 0.024948059), (3, 0.72641796)]),
#    (370,
#     [(0, 0.030977614), (1, 0.08181811), (2, 0.060535185), (3, 0.48878673)])]),
#  ([(0, 0.23173065), (1, 0.47256112), (3, 0.28675824)],
#   [(35, [3]),
#    (133, [0]),
#    (172, [0]),
#    (173, [0]),
#    (220, [1]),
#    (286, [0]),
#    (371, [1]),
#    (372, [1]),
#    (373, [1, 3, 0]),
#    (374, [3]),
#    (375, [3]),
#    (376, [1, 3, 0]),
#    (377, [1, 3, 0]),
#    (378, [1, 3, 0]),
#    (379, [1]),
#    (380, [1, 3, 0]),
#    (381, [1]),
#    (382, [3, 0]),
#    (383, [1, 3, 0]),
#    (384, [0, 3, 1]),
#    (385, [1]),
#    (386, [3, 1, 0]),
#    (387, [1]),
#    (388, [1, 3, 0]),
#    (389, [1, 3, 0]),
#    (390, [1]),
#    (391, [1, 3, 0])],
#   [(35, [(3, 0.9980536)]),
#    (133, [(0, 1.9997082)]),
#    (172, [(0, 0.99990314)]),
#    (173, [(0, 0.9997873)]),
#    (220, [(1, 1.9998688)]),
#    (286, [(0, 0.9987654)]),
#    (371, [(1, 1.9997647)]),
#    (372, [(1, 0.9996297)]),
#    (373, [(0, 0.0914553), (1, 0.5798526), (3, 0.53334534)]),
#    (374, [(3, 0.9887253)]),
#    (375, [(3, 0.9995847)]),
#    (376, [(0, 0.046221737), (1, 0.28757378), (3, 0.26346153)]),
#    (377, [(0, 0.046221737), (1, 0.28757378), (3, 0.26346153)]),
#    (378, [(0, 0.046221737), (1, 0.28757378), (3, 0.26346153)]),
#    (379, [(1, 0.9999268)]),
#    (380, [(0, 0.046221737), (1, 0.28757378), (3, 0.26346153)]),
#    (381, [(1, 0.9982867)]),
#    (382, [(0, 0.21069054), (3, 0.78146374)]),
#    (383, [(0, 0.093442075), (1, 0.5703688), (3, 0.5204354)]),
#    (384, [(0, 0.61127967), (1, 0.011151331), (3, 0.37681663)]),
#    (385, [(1, 0.998347)]),
#    (386, [(0, 0.036823772), (1, 0.06289186), (3, 0.8997691)]),
#    (387, [(1, 0.99995637)]),
#    (388, [(0, 0.046221737), (1, 0.28757378), (3, 0.26346153)]),
#    (389, [(0, 0.046221737), (1, 0.28757378), (3, 0.26346153)]),
#    (390, [(1, 0.9997316)]),
#    (391, [(0, 0.046721037), (1, 0.2851844), (3, 0.2602177)])]),
#  ([(0, 0.26017082), (1, 0.013222759), (2, 0.10425354), (3, 0.6223529)],
#   [(55, [3]),
#    (61, [0]),
#    (69, [3]),
#    (73, [3]),
#    (139, [2]),
#    (172, [0]),
#    (185, [0]),
#    (326, [3, 2, 0]),
#    (359, [3, 2, 0]),
#    (364, [3, 2]),
#    (391, [3, 2, 0]),
#    (392, [3]),
#    (393, [3]),
#    (394, [3]),
#    (395, [3, 0]),
#    (396, [3]),
#    (397, [3]),
#    (398, [3, 2, 0])],
#   [(55, [(3, 0.9999764)]),
#    (61, [(0, 1.999467)]),
#    (69, [(3, 0.99998784)]),
#    (73, [(3, 0.99982554)]),
#    (139, [(2, 0.9970668)]),
#    (172, [(0, 0.9998939)]),
#    (185, [(0, 0.9945661)]),
#    (326, [(0, 0.056214914), (2, 0.08001582), (3, 0.50754154)]),
#    (359, [(0, 0.09278144), (2, 0.12720086), (3, 1.0458637)]),
#    (364, [(2, 0.40673572), (3, 0.5911833)]),
#    (391, [(0, 0.04639072), (2, 0.06360043), (3, 0.5229319)]),
#    (392, [(3, 0.99979573)]),
#    (393, [(3, 0.9999439)]),
#    (394, [(3, 0.9851481)]),
#    (395, [(0, 0.49290216), (3, 0.50547516)]),
#    (396, [(3, 0.9952447)]),
#    (397, [(3, 0.9999443)]),
#    (398, [(0, 0.046788707), (2, 0.06310714), (3, 0.5260602)])]),
#  ([(0, 0.4443348), (1, 0.20321816), (2, 0.18492767), (3, 0.16751938)],
#   [(3, [1]),
#    (5, [1]),
#    (13, [3, 2]),
#    (89, [0]),
#    (133, [0]),
#    (139, [2]),
#    (151, [0]),
#    (155, [0]),
#    (172, [0]),
#    (215, [1, 0]),
#    (263, [2]),
#    (293, [2]),
#    (309, [3]),
#    (310, [2]),
#    (350, [1]),
#    (356, [0]),
#    (365, [1, 3]),
#    (374, [3]),
#    (399, [0, 2]),
#    (400, [3, 1, 0, 2]),
#    (401, [2, 3, 1, 0]),
#    (402, [3]),
#    (403, [2]),
#    (404, [0]),
#    (405, [1]),
#    (406, [0]),
#    (407, [2, 3, 1, 0]),
#    (408, [0]),
#    (409, [2]),
#    (410, [0]),
#    (411, [1]),
#    (412, [0, 1]),
#    (413, [0]),
#    (414, [0]),
#    (415, [0]),
#    (416, [0]),
#    (417, [2, 3, 1, 0]),
#    (418, [3]),
#    (419, [2, 3, 1, 0]),
#    (420, [0]),
#    (421, [0]),
#    (422, [2, 3, 1, 0]),
#    (423, [2, 3, 1, 0]),
#    (424, [1]),
#    (425, [0]),
#    (426, [1]),
#    (427, [2, 3, 1, 0]),
#    (428, [2]),
#    (429, [0, 3])],
#   [(3, [(1, 0.9995312)]),
#    (5, [(1, 1.9991108)]),
#    (13, [(2, 0.021919234), (3, 2.95931)]),
#    (89, [(0, 1.9997121)]),
#    (133, [(0, 0.9999367)]),
#    (139, [(2, 0.99866927)]),
#    (151, [(0, 0.99904376)]),
#    (155, [(0, 2.9996297)]),
#    (172, [(0, 0.99996)]),
#    (215, [(0, 0.15483159), (1, 0.8450268)]),
#    (263, [(2, 0.99993664)]),
#    (293, [(2, 0.99993473)]),
#    (309, [(3, 0.99945384)]),
#    (310, [(2, 0.9828925)]),
#    (350, [(1, 0.9998281)]),
#    (356, [(0, 0.99973506)]),
#    (365, [(1, 0.51940113), (3, 0.48010373)]),
#    (374, [(3, 0.9821801)]),
#    (399, [(0, 0.97484815), (2, 0.014639071)]),
#    (400, [(0, 0.13032812), (1, 0.14450678), (2, 0.055985447), (3, 0.6661248)]),
#    (401, [(0, 0.10131535), (1, 0.13028324), (2, 0.16658285), (3, 0.164424)]),
#    (402, [(3, 0.96160346)]),
#    (403, [(2, 0.99948585)]),
#    (404, [(0, 0.9996944)]),
#    (405, [(1, 0.99715346)]),
#    (406, [(0, 0.9991989)]),
#    (407, [(0, 0.10131535), (1, 0.13028324), (2, 0.16658285), (3, 0.164424)]),
#    (408, [(0, 0.999584)]),
#    (409, [(2, 1.9997624)]),
#    (410, [(0, 0.9996936)]),
#    (411, [(1, 1.9943674)]),
#    (412, [(0, 0.9753888), (1, 0.014420491)]),
#    (413, [(0, 0.99982965)]),
#    (414, [(0, 0.9995636)]),
#    (415, [(0, 0.9967737)]),
#    (416, [(0, 0.99962246)]),
#    (417, [(0, 0.10130616), (1, 0.13024299), (2, 0.16591014), (3, 0.16399711)]),
#    (418, [(3, 0.99834406)]),
#    (419, [(0, 0.20264779), (1, 0.2606459), (2, 0.3345097), (3, 0.32970008)]),
#    (420, [(0, 1.9996643)]),
#    (421, [(0, 0.99720246)]),
#    (422, [(0, 0.20243013), (1, 0.2629113), (2, 0.33144352), (3, 0.32750466)]),
#    (423, [(0, 0.20245165), (1, 0.27413255), (2, 0.33252355), (3, 0.328486)]),
#    (424, [(1, 0.9997518)]),
#    (425, [(0, 1.9869571)]),
#    (426, [(1, 0.9907933)]),
#    (427, [(0, 0.101672664), (1, 0.1297154), (2, 0.1718096), (3, 0.16718505)]),
#    (428, [(2, 1.9995133)]),
#    (429, [(0, 0.9827655), (3, 0.017113538)])]),
#  ([(0, 0.2411273), (1, 0.13775109), (2, 0.59485), (3, 0.026271591)],
#   [(74, [0]),
#    (81, [2]),
#    (265, [2]),
#    (293, [2]),
#    (312, [0]),
#    (430, [1]),
#    (431, [2, 1, 0]),
#    (432, [2, 0, 1])],
#   [(74, [(0, 0.9995384)]),
#    (81, [(2, 0.99998796)]),
#    (265, [(2, 0.9999714)]),
#    (293, [(2, 1.9999752)]),
#    (312, [(0, 0.9997714)]),
#    (430, [(1, 0.9987554)]),
#    (431, [(0, 0.04289263), (1, 0.058139257), (2, 0.49272004)]),
#    (432, [(0, 0.020720277), (1, 0.014527768), (2, 0.96295315)])]),
#  ([(0, 0.33904418), (1, 0.059109386), (2, 0.120441265), (3, 0.48140517)],
#   [(53, [3, 2, 0]),
#    (54, [1, 0, 3]),
#    (55, [3]),
#    (73, [3]),
#    (138, [2]),
#    (139, [2]),
#    (172, [0]),
#    (301, [0]),
#    (343, [0]),
#    (365, [3, 1]),
#    (392, [3]),
#    (393, [3]),
#    (433, [0]),
#    (434, [3, 0]),
#    (435, [3, 2, 0, 1]),
#    (436, [0]),
#    (437, [3, 2, 0, 1]),
#    (438, [3, 2, 0, 1]),
#    (439, [3, 2, 0, 1]),
#    (440, [0, 2, 3, 1]),
#    (441, [0])],
#   [(53, [(0, 0.021243365), (2, 0.026788304), (3, 0.81979865)]),
#    (54, [(0, 0.06747636), (1, 0.8773306), (3, 0.03531597)]),
#    (55, [(3, 1.9999312)]),
#    (73, [(3, 0.99974287)]),
#    (138, [(2, 0.9949896)]),
#    (139, [(2, 0.9977448)]),
#    (172, [(0, 0.9999307)]),
#    (301, [(0, 0.9997855)]),
#    (343, [(0, 0.9997352)]),
#    (365, [(1, 0.0691841), (3, 0.93054456)]),
#    (392, [(3, 1.9994004)]),
#    (393, [(3, 0.9998918)]),
#    (433, [(0, 0.99949515)]),
#    (434, [(0, 0.11163629), (3, 0.88830376)]),
#    (435,
#     [(0, 0.067080945), (1, 0.023518164), (2, 0.0845891), (3, 0.43090737)]),
#    (436, [(0, 0.9997916)]),
#    (437,
#     [(0, 0.06664313), (1, 0.023316296), (2, 0.08457149), (3, 0.43498942)]),
#    (438,
#     [(0, 0.067080945), (1, 0.023518164), (2, 0.0845891), (3, 0.43090737)]),
#    (439,
#     [(0, 0.06707701), (1, 0.023514451), (2, 0.08458996), (3, 0.43097705)]),
#    (440, [(0, 0.8369969), (1, 0.018433815), (2, 0.07128106), (3, 0.07072342)]),
#    (441, [(0, 0.999261)])]),
#  ([(0, 0.24909228), (1, 0.024480328), (2, 0.16097617), (3, 0.56545126)],
#   [(9, [3]),
#    (43, [2, 3]),
#    (55, [3]),
#    (309, [3]),
#    (442, [3, 2, 0]),
#    (443, [0]),
#    (444, [0]),
#    (445, [3, 2, 0]),
#    (446, [3, 0, 2]),
#    (447, [3, 2, 0]),
#    (448, [3, 2, 0])],
#   [(9, [(3, 0.99996203)]),
#    (43, [(2, 0.97869015), (3, 0.015389517)]),
#    (55, [(3, 0.99997187)]),
#    (309, [(3, 0.9998863)]),
#    (442, [(0, 0.042425465), (2, 0.09819522), (3, 0.47988093)]),
#    (443, [(0, 0.99403524)]),
#    (444, [(0, 0.99837667)]),
#    (445, [(0, 0.042425465), (2, 0.09819522), (3, 0.47988093)]),
#    (446, [(0, 0.1964251), (2, 0.062916346), (3, 0.7368793)]),
#    (447, [(0, 0.042425465), (2, 0.09819522), (3, 0.47988093)]),
#    (448, [(0, 0.042425465), (2, 0.09819522), (3, 0.47988093)])]),
#  ([(0, 0.81248367), (1, 0.06250532), (2, 0.06250552), (3, 0.06250548)],
#   [(151, [0]), (155, [0]), (413, [0])],
#   [(151, [(0, 0.9997633)]), (155, [(0, 0.9999708)]), (413, [(0, 0.9999594)])]),
#  ([(0, 0.018673869), (1, 0.018812768), (2, 0.2424456), (3, 0.72006774)],
#   [(55, [3]),
#    (79, [3]),
#    (117, [3]),
#    (257, [3]),
#    (340, [2]),
#    (393, [3]),
#    (449, [3, 2]),
#    (450, [3, 2]),
#    (451, [3, 2]),
#    (452, [2]),
#    (453, [3, 2]),
#    (454, [3, 2]),
#    (455, [3, 2])],
#   [(55, [(3, 0.9999769)]),
#    (79, [(3, 0.9997656)]),
#    (117, [(3, 0.9998775)]),
#    (257, [(3, 0.9989025)]),
#    (340, [(2, 0.9998214)]),
#    (393, [(3, 1.9998788)]),
#    (449, [(2, 0.17316756), (3, 0.81966907)]),
#    (450, [(2, 0.25107247), (3, 0.47201252)]),
#    (451, [(2, 0.14656225), (3, 0.53245133)]),
#    (452, [(2, 0.99949753)]),
#    (453, [(2, 0.14635113), (3, 0.5313362)]),
#    (454, [(2, 0.14635113), (3, 0.5313362)]),
#    (455, [(2, 0.14390907), (3, 0.54130477)])]),
#  ([(0, 0.08333656), (1, 0.7499887), (2, 0.08333717), (3, 0.08333763)],
#   [(456, [1]), (457, [1])],
#   [(456, [(1, 0.99991757)]), (457, [(1, 0.99996656)])]),
#  ([(0, 0.38719645), (1, 0.17256433), (2, 0.027833184), (3, 0.412406)],
#   [(5, [1]),
#    (61, [0]),
#    (349, [0]),
#    (458, [3, 1, 0]),
#    (459, [3, 1, 0]),
#    (460, [3, 1, 0]),
#    (461, [3]),
#    (462, [3, 1, 0]),
#    (463, [3]),
#    (464, [0])],
#   [(5, [(1, 0.99930227)]),
#    (61, [(0, 0.9998537)]),
#    (349, [(0, 0.99892783)]),
#    (458, [(0, 0.081817284), (1, 0.08593512), (3, 0.38993487)]),
#    (459, [(0, 0.081817284), (1, 0.08593512), (3, 0.38993487)]),
#    (460, [(0, 0.081817284), (1, 0.08593512), (3, 0.38993487)]),
#    (461, [(3, 0.99953943)]),
#    (462, [(0, 0.081817284), (1, 0.08593512), (3, 0.38993487)]),
#    (463, [(3, 0.9985533)]),
#    (464, [(0, 0.9994109)])]),
#  ([(0, 0.27055323), (1, 0.6261988), (2, 0.05153186), (3, 0.051716156)],
#   [(64, [1, 0]), (220, [1]), (301, [0]), (465, [1]), (466, [1, 0])],
#   [(64, [(0, 0.051953066), (1, 0.44175205)]),
#    (220, [(1, 0.99996835)]),
#    (301, [(0, 0.9997294)]),
#    (465, [(1, 0.9999297)]),
#    (466, [(0, 0.051955592), (1, 0.4417508)])]),
#  ([(0, 0.08341179), (1, 0.08341665), (2, 0.41763392), (3, 0.4155377)],
#   [(467, [2]), (468, [3])],
#   [(467, [(2, 0.99991435)]), (468, [(3, 0.99543583)])]),
#  ([(0, 0.19414257), (1, 0.20877646), (2, 0.22818133), (3, 0.36889964)],
#   [(92, [3, 2, 1])],
#   [(92, [(1, 0.025911178), (2, 0.05104545), (3, 0.24015297)])]),
#  ([(0, 0.48192972), (1, 0.29128835), (3, 0.22022776)],
#   [(53, [3, 1, 0]),
#    (61, [0]),
#    (73, [3]),
#    (188, [0]),
#    (238, [0, 1]),
#    (312, [0]),
#    (349, [0]),
#    (430, [1]),
#    (469, [0]),
#    (470, [3, 1, 0]),
#    (471, [1, 3]),
#    (472, [3, 0, 1]),
#    (473, [1]),
#    (474, [0]),
#    (475, [0]),
#    (476, [3]),
#    (477, [0, 1]),
#    (478, [3, 1, 0]),
#    (479, [0, 3, 1]),
#    (480, [3, 1, 0]),
#    (481, [1, 0, 3]),
#    (482, [0]),
#    (483, [1, 0, 3]),
#    (484, [1]),
#    (485, [0]),
#    (486, [3, 1, 0]),
#    (487, [0]),
#    (488, [0]),
#    (489, [3, 1, 0]),
#    (490, [0]),
#    (491, [3, 1, 0]),
#    (492, [0]),
#    (493, [3, 1, 0]),
#    (494, [3]),
#    (495, [3, 1, 0]),
#    (496, [0, 3, 1]),
#    (497, [3, 1, 0]),
#    (498, [3, 1, 0]),
#    (499, [1])],
#   [(53, [(0, 0.054059006), (1, 0.09233291), (3, 0.6369773)]),
#    (61, [(0, 0.9998967)]),
#    (73, [(3, 1.9987171)]),
#    (188, [(0, 0.99952394)]),
#    (238, [(0, 0.8087338), (1, 0.18612663)]),
#    (312, [(0, 0.9999263)]),
#    (349, [(0, 0.9992533)]),
#    (430, [(1, 0.9995925)]),
#    (469, [(0, 0.99352765)]),
#    (470, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (471, [(1, 0.9624963), (3, 0.010602311)]),
#    (472, [(0, 0.20904645), (1, 0.043075833), (3, 0.7414035)]),
#    (473, [(1, 2.9990861)]),
#    (474, [(0, 0.99872595)]),
#    (475, [(0, 0.9984542)]),
#    (476, [(3, 0.99865884)]),
#    (477, [(0, 0.91403323), (1, 0.081397414)]),
#    (478, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (479, [(0, 1.8540696), (1, 0.3091393), (3, 0.35998297)]),
#    (480, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (481, [(0, 0.15243512), (1, 0.54095143), (3, 0.122224405)]),
#    (482, [(0, 0.99983174)]),
#    (483, [(0, 0.101497374), (1, 0.8466257), (3, 0.017238136)]),
#    (484, [(1, 0.9829009)]),
#    (485, [(0, 0.99985117)]),
#    (486, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (487, [(0, 0.99966687)]),
#    (488, [(0, 0.99972785)]),
#    (489, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (490, [(0, 0.99786115)]),
#    (491, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (492, [(0, 0.99903524)]),
#    (493, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (494, [(3, 0.9988506)]),
#    (495, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (496, [(0, 0.39421576), (1, 0.15258281), (3, 0.2247818)]),
#    (497, [(0, 0.11523215), (1, 0.19691554), (3, 0.22600843)]),
#    (498, [(0, 0.11524532), (1, 0.19681467), (3, 0.22603726)]),
#    (499, [(1, 0.99822956)])]),
#  ([(0, 0.19657166), (1, 0.22987963), (2, 0.03771722), (3, 0.53583145)],
#   [(85, [3]),
#    (89, [0]),
#    (107, [1]),
#    (494, [3]),
#    (500, [3, 1, 0]),
#    (501, [3, 1, 0]),
#    (502, [3, 1, 0])],
#   [(85, [(3, 0.9996958)]),
#    (89, [(0, 0.99939054)]),
#    (107, [(1, 0.9983519)]),
#    (494, [(3, 0.99967325)]),
#    (500, [(0, 0.029222189), (1, 0.10496536), (3, 0.4648948)]),
#    (501, [(0, 0.029222189), (1, 0.10496536), (3, 0.4648948)]),
#    (502, [(0, 0.029222189), (1, 0.10496536), (3, 0.4648948)])]),
#  ([(0, 0.31227818), (1, 0.18241851), (2, 0.017647726), (3, 0.48765555)],
#   [(5, [1]),
#    (6, [1]),
#    (55, [3]),
#    (65, [3]),
#    (173, [0]),
#    (227, [3]),
#    (458, [3, 1, 0]),
#    (460, [3, 1, 0]),
#    (487, [0]),
#    (503, [3]),
#    (504, [3, 1, 0]),
#    (505, [0]),
#    (506, [3, 1, 0])],
#   [(5, [(1, 0.9993691)]),
#    (6, [(1, 0.99778026)]),
#    (55, [(3, 1.9999343)]),
#    (65, [(3, 0.9999494)]),
#    (173, [(0, 1.999679)]),
#    (227, [(3, 0.99804187)]),
#    (458, [(0, 0.061040323), (1, 0.093999356), (3, 0.44089478)]),
#    (460, [(0, 0.061040323), (1, 0.093999356), (3, 0.44089478)]),
#    (487, [(0, 0.9992991)]),
#    (503, [(3, 0.99984884)]),
#    (504, [(0, 0.061040323), (1, 0.093999356), (3, 0.44089478)]),
#    (505, [(0, 0.9984159)]),
#    (506, [(0, 0.061040323), (1, 0.093999356), (3, 0.44089478)])]),
#  ([(0, 0.36808017), (1, 0.03949093), (2, 0.23164678), (3, 0.36078212)],
#   [(53, [3, 2, 0]),
#    (172, [0]),
#    (257, [3]),
#    (263, [2]),
#    (507, [0]),
#    (508, [3, 2, 0])],
#   [(53, [(0, 0.028420538), (2, 0.06243202), (3, 0.7382763)]),
#    (172, [(0, 0.9999406)]),
#    (257, [(3, 0.99722975)]),
#    (263, [(2, 0.9999407)]),
#    (507, [(0, 0.99961233)]),
#    (508, [(0, 0.07390149), (2, 0.1668473), (3, 0.32033795)])]),
#  ([(0, 0.513103), (1, 0.20973253), (2, 0.02786141), (3, 0.2493031)],
#   [(183, [0]), (307, [0]), (509, [0]), (510, [3]), (511, [0]), (512, [1, 0])],
#   [(183, [(0, 0.99969137)]),
#    (307, [(0, 0.99983805)]),
#    (509, [(0, 0.9999346)]),
#    (510, [(3, 1.9818435)]),
#    (511, [(0, 0.99230194)]),
#    (512, [(0, 0.36535576), (1, 1.6301259)])]),
#  ([(0, 0.3125747), (1, 0.31217894), (2, 0.06251404), (3, 0.31273234)],
#   [(84, [3]), (110, [1]), (172, [0])],
#   [(84, [(3, 0.99992895)]), (110, [(1, 0.99845624)]), (172, [(0, 0.999927)])]),
#  ([(0, 0.035756327), (1, 0.03575961), (2, 0.46581766), (3, 0.4626664)],
#   [(2, [2]), (80, [3]), (81, [2]), (116, [3]), (513, [3])],
#   [(2, [(2, 0.9998395)]),
#    (80, [(3, 0.99986)]),
#    (81, [(2, 1.9999529)]),
#    (116, [(3, 0.9999381)]),
#    (513, [(3, 0.98507094)])]),
#  ([(0, 0.25), (1, 0.25), (2, 0.25), (3, 0.25)], [], []),
#  ([(0, 0.12511595), (1, 0.1251454), (2, 0.12509272), (3, 0.62464595)],
#   [(396, [3])],
#   [(396, [(3, 0.9989386)])]),
#  ([(0, 0.8299591), (2, 0.11426625), (3, 0.05228559)],
#   [(1, [0]),
#    (49, [0]),
#    (61, [0]),
#    (84, [3]),
# ...
#    (4850, [(2, 0.10764763), (3, 0.5674909)]),
#    (4851, [(2, 0.10764763), (3, 0.5674909)]),
#    (4852, [(2, 0.21529526), (3, 1.1349818)])]),
#  ([(0, 0.028140444), (1, 0.1913585), (2, 0.028916163), (3, 0.75158495)],
#   [(255, [3, 1]),
#    (2450, [1]),
#    (4853, [3, 1]),
#    (4854, [3, 1]),
#    (4855, [3]),
#    (4856, [3, 1]),
#    (4857, [3, 1]),
#    (4858, [3]),
#    (4859, [3, 1]),
#    (4860, [3, 1])],
#   [(255, [(1, 0.07553053), (3, 0.5831367)]),
#    (2450, [(1, 0.9962879)]),
#    (4853, [(1, 0.07553053), (3, 0.5831367)]),
#    (4854, [(1, 0.07553053), (3, 0.5831367)]),
#    (4855, [(3, 0.9997005)]),
#    (4856, [(1, 0.07553053), (3, 0.5831367)]),
#    (4857, [(1, 0.012727325), (3, 0.9837759)]),
#    (4858, [(3, 0.99727064)]),
#    (4859, [(1, 0.07553053), (3, 0.5831367)]),
#    (4860, [(1, 0.07553053), (3, 0.5831367)])]),
#  ([(0, 0.32133394), (1, 0.10642708), (2, 0.23962191), (3, 0.33261704)],
#   [(409, [2]),
#    (479, [0, 3, 2, 1]),
#    (741, [0]),
#    (1201, [1]),
#    (1240, [0]),
#    (1266, [0]),
#    (1360, [2]),
#    (1529, [3]),
#    (2009, [3, 1, 0]),
#    (2575, [0, 2, 3]),
#    (3049, [3]),
#    (4861, [3, 2, 0, 1]),
#    (4862, [3, 2, 0, 1]),
#    (4863, [3, 2, 0, 1]),
#    (4864, [3, 2, 0, 1]),
#    (4865, [3, 2, 0, 1])],
#   [(409, [(2, 0.99989724)]),
#    (479, [(0, 0.4512302), (1, 0.03294879), (2, 0.12532987), (3, 0.2057576)]),
#    (741, [(0, 0.988263)]),
#    (1201, [(1, 0.990973)]),
#    (1240, [(0, 0.9988924)]),
#    (1266, [(0, 0.9996881)]),
#    (1360, [(2, 0.9995924)]),
#    (1529, [(3, 0.99985707)]),
#    (2009, [(0, 0.052880432), (1, 0.054748874), (3, 0.8896495)]),
#    (2575, [(0, 0.679354), (2, 0.22250608), (3, 0.08511195)]),
#    (3049, [(3, 0.99982774)]),
#    (4861,
#     [(0, 0.06394878), (1, 0.047827695), (2, 0.18544386), (3, 0.29457158)]),
#    (4862,
#     [(0, 0.06394878), (1, 0.047827695), (2, 0.18544386), (3, 0.29457158)]),
#    (4863,
#     [(0, 0.06394878), (1, 0.047827695), (2, 0.18544386), (3, 0.29457158)]),
#    (4864,
#     [(0, 0.06394878), (1, 0.047827695), (2, 0.18544386), (3, 0.29457158)]),
#    (4865,
#     [(0, 0.06394878), (1, 0.047827695), (2, 0.18544386), (3, 0.29457158)])]),
#  ([(0, 0.048370276), (1, 0.1817413), (2, 0.11226056), (3, 0.6576278)],
#   [(26, [1]),
#    (69, [3]),
#    (79, [3]),
#    (80, [3]),
#    (119, [3, 2]),
#    (172, [0]),
#    (243, [1]),
#    (293, [2]),
#    (361, [3]),
#    (395, [3, 1, 0]),
#    (455, [3, 1, 2]),
#    (829, [3, 1, 2]),
#    (952, [1]),
#    (1323, [3, 1, 2]),
#    (1426, [3, 1, 2]),
#    (1518, [3, 1, 2]),
#    (1747, [3]),
#    (2997, [3, 1, 2]),
#    (4851, [3, 1, 2]),
#    (4852, [3, 1, 2, 0]),
#    (4866, [3, 2, 1]),
#    (4867, [3, 1, 2]),
#    (4868, [3, 1, 2]),
#    (4869, [3, 1, 2]),
#    (4870, [3, 1, 2]),
#    (4871, [3, 1, 2])],
#   [(26, [(1, 0.99923444)]),
#    (69, [(3, 2.9999604)]),
#    (79, [(3, 2.9992378)]),
#    (80, [(3, 0.9999306)]),
#    (119, [(2, 0.01114054), (3, 0.98502004)]),
#    (172, [(0, 0.9991165)]),
#    (243, [(1, 0.99919343)]),
#    (293, [(2, 1.9996476)]),
#    (361, [(3, 0.99985886)]),
#    (395, [(0, 0.08159009), (1, 0.27072844), (3, 0.6470454)]),
#    (455, [(1, 0.08369869), (2, 0.06785713), (3, 0.51654255)]),
#    (829, [(1, 0.36283082), (2, 0.023972197), (3, 0.60732156)]),
#    (952, [(1, 0.99958366)]),
#    (1323, [(1, 0.23728247), (2, 0.023909321), (3, 0.7382034)]),
#    (1426, [(1, 0.08461855), (2, 0.06897156), (3, 0.5067576)]),
#    (1518, [(1, 0.067390494), (2, 0.014043196), (3, 0.9111753)]),
#    (1747, [(3, 0.99624056)]),
#    (2997, [(1, 0.08461855), (2, 0.06897156), (3, 0.5067576)]),
#    (4851, [(1, 0.08461855), (2, 0.06897156), (3, 0.5067576)]),
#    (4852, [(0, 0.011626744), (1, 0.1692371), (2, 0.13794312), (3, 1.0135152)]),
#    (4866, [(1, 0.067673296), (2, 0.19251175), (3, 0.4842498)]),
#    (4867, [(1, 0.08461855), (2, 0.06897156), (3, 0.5067576)]),
#    (4868, [(1, 0.08461855), (2, 0.06897156), (3, 0.5067576)]),
#    (4869, [(1, 0.18946923), (2, 0.06084398), (3, 0.44719234)]),
#    (4870, [(1, 0.08461855), (2, 0.06897156), (3, 0.5067576)]),
#    (4871, [(1, 0.08461855), (2, 0.06897156), (3, 0.5067576)])]),
#  ([(0, 0.81196684), (1, 0.06267862), (2, 0.062676586), (3, 0.06267796)],
#   [(170, [0]), (1585, [0]), (2734, [0])],
#   [(170, [(0, 0.9999767)]),
#    (1585, [(0, 0.99949414)]),
#    (2734, [(0, 0.99046755)])]),
#  ([(0, 0.2592032), (1, 0.04969386), (2, 0.6411862), (3, 0.049916804)],
#   [(272, [2]), (1294, [0]), (3481, [2, 0]), (4872, [2, 0]), (4873, [2, 0])],
#   [(272, [(2, 0.99997234)]),
#    (1294, [(0, 0.9952026)]),
#    (3481, [(0, 0.010670137), (2, 0.98558384)]),
#    (4872, [(0, 0.041338738), (2, 0.5358496)]),
#    (4873, [(0, 0.041338738), (2, 0.5358496)])]),
#  ([(0, 0.40238348), (1, 0.037515946), (2, 0.038536128), (3, 0.5215645)],
#   [(204, [0]),
#    (1043, [0]),
#    (4874, [3, 0]),
#    (4875, [3, 0]),
#    (4876, [3, 0]),
#    (4877, [3, 0]),
#    (4878, [3, 0]),
#    (4879, [3, 0]),
#    (4880, [3, 0])],
#   [(204, [(0, 0.9998676)]),
#    (1043, [(0, 0.99939173)]),
#    (4874, [(0, 0.0808328), (3, 0.4857387)]),
#    (4875, [(0, 0.08083218), (3, 0.4857428)]),
#    (4876, [(0, 0.0808328), (3, 0.4857387)]),
#    (4877, [(0, 0.0808328), (3, 0.4857387)]),
#    (4878, [(0, 0.0808328), (3, 0.4857387)]),
#    (4879, [(0, 0.0808328), (3, 0.4857387)]),
#    (4880, [(0, 0.0808328), (3, 0.4857387)])]),
#  ([(0, 0.03845414), (1, 0.0390103), (2, 0.8824013), (3, 0.040134322)],
#   [(1840, [2]),
#    (2432, [2]),
#    (4874, [2]),
#    (4880, [2]),
#    (4881, [2]),
#    (4882, [2]),
#    (4883, [2])],
#   [(1840, [(2, 0.9960265)]),
#    (2432, [(2, 1.3983886)]),
#    (4874, [(2, 0.6467968)]),
#    (4880, [(2, 0.6467968)]),
#    (4881, [(2, 0.6467968)]),
#    (4882, [(2, 0.6467968)]),
#    (4883, [(2, 0.6467968)])]),
#  ([(0, 0.21043144), (1, 0.40503934), (2, 0.0832708), (3, 0.3012584)],
#   [(69, [3]),
#    (73, [3]),
#    (78, [1]),
#    (80, [3]),
#    (455, [3, 1, 2, 0]),
#    (665, [3, 1, 2, 0]),
#    (709, [1, 0]),
#    (766, [0, 3, 1, 2]),
#    (849, [1]),
#    (880, [1]),
#    (1043, [0]),
#    (2293, [2]),
#    (3266, [3, 1, 2, 0]),
#    (3276, [1]),
#    (3658, [0]),
#    (3926, [1, 0, 2, 3]),
#    (4106, [1, 2, 0]),
#    (4179, [1, 3]),
#    (4251, [0, 3, 1]),
#    (4368, [0, 1, 3]),
#    (4658, [3, 1, 2, 0]),
#    (4884, [3, 1, 2, 0]),
#    (4885, [3, 1, 2, 0]),
#    (4886, [3, 1, 2, 0]),
#    (4887, [3, 1, 2, 0]),
#    (4888, [3, 1, 2]),
#    (4889, [3, 1, 2]),
#    (4890, [3, 1, 2, 0]),
#    (4891, [3, 1, 2, 0]),
#    (4892, [3, 1, 2, 0])],
#   [(69, [(3, 0.9999628)]),
#    (73, [(3, 0.9994783)]),
#    (78, [(1, 0.9999172)]),
#    (80, [(3, 0.99980116)]),
#    (455,
#     [(0, 0.04040975), (1, 0.23643196), (2, 0.055879626), (3, 0.27473003)]),
#    (665,
#     [(0, 0.035194024), (1, 0.20430736), (2, 0.049144313), (3, 0.37221885)]),
#    (709, [(0, 0.15638322), (1, 0.84338075)]),
#    (766,
#     [(0, 0.8180379), (1, 0.046389583), (2, 0.010925381), (3, 0.050518483)]),
#    (849, [(1, 0.99916154)]),
#    (880, [(1, 0.99963206)]),
#    (1043, [(0, 0.9989592)]),
#    (2293, [(2, 0.9983494)]),
#    (3266,
#     [(0, 0.040906172), (1, 0.23688948), (2, 0.056282636), (3, 0.26784664)]),
#    (3276, [(1, 0.99461406)]),
#    (3658, [(0, 0.9983527)]),
#    (3926,
#     [(0, 0.0751835), (1, 0.8497099), (2, 0.049335036), (3, 0.018271197)]),
#    (4106, [(0, 0.0105099855), (1, 0.7532333), (2, 0.23043421)]),
#    (4179, [(1, 0.9811998), (3, 0.0147125805)]),
#    (4251, [(0, 0.89388144), (1, 0.027004143), (3, 0.029145438)]),
#    (4368, [(0, 0.9342901), (1, 0.047562193), (3, 0.0131882345)]),
#    (4658,
#     [(0, 0.04093827), (1, 0.23704821), (2, 0.056326356), (3, 0.2672907)]),
#    (4884,
#     [(0, 0.039710294), (1, 0.23781617), (2, 0.05850001), (3, 0.2776164)]),
#    (4885,
#     [(0, 0.04093827), (1, 0.23704821), (2, 0.056326356), (3, 0.2672907)]),
#    (4886,
#     [(0, 0.04093827), (1, 0.23704821), (2, 0.056326356), (3, 0.2672907)]),
#    (4887,
#     [(0, 0.04093827), (1, 0.23704821), (2, 0.056326356), (3, 0.2672907)]),
#    (4888, [(1, 0.023921974), (2, 0.010564648), (3, 0.95380545)]),
#    (4889, [(1, 0.35704368), (2, 0.032269772), (3, 0.5929409)]),
#    (4890,
#     [(0, 0.04093827), (1, 0.23704821), (2, 0.056326356), (3, 0.2672907)]),
#    (4891,
#     [(0, 0.04093827), (1, 0.23704821), (2, 0.056326356), (3, 0.2672907)]),
#    (4892,
#     [(0, 0.04093827), (1, 0.23704821), (2, 0.056326356), (3, 0.2672907)])]),
#  ([(0, 0.045201708), (1, 0.2339514), (2, 0.24338758), (3, 0.47745928)],
#   [(69, [3]), (80, [3]), (1663, [1, 3, 2]), (4893, [3, 2, 1]), (4894, [2, 3])],
#   [(69, [(3, 0.99997795)]),
#    (80, [(3, 0.99988323)]),
#    (1663, [(1, 0.9580668), (2, 0.012247172), (3, 0.01966639)]),
#    (4893, [(1, 0.09603885), (2, 0.14302932), (3, 0.38009325)]),
#    (4894, [(2, 0.95643264), (3, 0.02206506)])]),
#  ([(0, 0.77666944), (1, 0.07306763), (2, 0.07474486), (3, 0.075518094)],
#   [(170, [0]), (1467, [0]), (4895, [0, 3]), (4896, [0, 3])],
#   [(170, [(0, 0.9999747)]),
#    (1467, [(0, 0.9985394)]),
#    (4895, [(0, 0.2734073), (3, 0.010810158)]),
#    (4896, [(0, 0.2734073), (3, 0.010810158)])]),
#  ([(0, 0.45890146), (1, 0.04637517), (2, 0.4474861), (3, 0.0472373)],
#   [(138, [2]),
#    (2863, [0]),
#    (4897, [0, 2]),
#    (4898, [2, 0]),
#    (4899, [2, 0]),
#    (4900, [2, 0])],
#   [(138, [(2, 0.99931645)]),
#    (2863, [(0, 0.99650985)]),
#    (4897, [(0, 0.9866172), (2, 0.0110811265)]),
#    (4898, [(0, 0.10373443), (2, 0.40665233)]),
#    (4899, [(0, 0.10373443), (2, 0.40665233)]),
#    (4900, [(0, 0.10373443), (2, 0.40665233)])]),
#  ([(0, 0.5171415), (1, 0.22859395), (2, 0.058438867), (3, 0.19582568)],
#   [(1, [0]),
#    (15, [1]),
#    (73, [3]),
#    (146, [0]),
#    (165, [1, 3]),
#    (169, [0]),
#    (253, [3, 1, 0, 2]),
#    (392, [3]),
#    (413, [0]),
#    (561, [0]),
#    (783, [0]),
#    (817, [3]),
#    (836, [1]),
#    (1035, [0]),
#    (1114, [0]),
#    (1183, [2, 3, 0]),
#    (1222, [3, 1, 0, 2]),
#    (2468, [0]),
#    (2471, [0]),
#    (2589, [1]),
#    (2645, [0]),
#    (3449, [3]),
#    (3556, [1, 0]),
#    (3886, [0]),
#    (4441, [1, 2, 0, 3]),
#    (4901, [0, 1, 2, 3]),
#    (4902, [1, 0, 2])],
#   [(1, [(0, 1.999958)]),
#    (15, [(1, 0.99928516)]),
#    (73, [(3, 0.99924034)]),
#    (146, [(0, 0.9998558)]),
#    (165, [(1, 0.9529709), (3, 0.011157376)]),
#    (169, [(0, 1.9976087)]),
#    (253, [(0, 0.12675439), (1, 0.15443707), (2, 0.04405128), (3, 0.20147625)]),
#    (392, [(3, 1.9982309)]),
#    (413, [(0, 0.9998688)]),
#    (561, [(0, 0.9996672)]),
#    (783, [(0, 0.99979466)]),
#    (817, [(3, 0.99963087)]),
#    (836, [(1, 0.99931675)]),
#    (1035, [(0, 0.9998943)]),
#    (1114, [(0, 0.9898124)]),
#    (1183, [(0, 0.01276551), (2, 0.9570963), (3, 0.017231017)]),
#    (1222, [(0, 0.26470512), (1, 0.30368268), (2, 0.08646404), (3, 0.4196582)]),
#    (2468, [(0, 0.99609566)]),
#    (2471, [(0, 0.9929498)]),
#    (2589, [(1, 0.99934083)]),
#    (2645, [(0, 0.9993058)]),
#    (3449, [(3, 0.99857455)]),
#    (3556, [(0, 0.019948123), (1, 0.97650564)]),
#    (3886, [(0, 0.9981698)]),
#    (4441, [(0, 0.20402303), (1, 0.5173636), (2, 0.25333056), (3, 0.02361493)]),
#    (4901, [(0, 0.58567727), (1, 0.21224098), (2, 0.0828124), (3, 0.03727273)]),
#    (4902, [(0, 0.30924), (1, 0.5861323), (2, 0.10050025)])]),
#  ([(0, 0.3866707), (1, 0.027796168), (2, 0.21867299), (3, 0.36686018)],
#   [(52, [0]),
#    (80, [3]),
#    (151, [0]),
#    (168, [0]),
#    (562, [3]),
#    (875, [2]),
#    (1747, [3]),
#    (3417, [2, 0, 3])],
#   [(52, [(0, 0.99917763)]),
#    (80, [(3, 0.9998545)]),
#    (151, [(0, 0.99879843)]),
#    (168, [(0, 0.9987839)]),
#    (562, [(3, 0.99987036)]),
#    (875, [(2, 0.99988765)]),
#    (1747, [(3, 0.98506594)]),
#    (3417, [(0, 0.22676666), (2, 0.7077593), (3, 0.06461013)])]),
#  ([(0, 0.27418268), (1, 0.16451657), (2, 0.045896888), (3, 0.51540387)],
#   [(31, [1, 3]), (57, [3, 0]), (70, [0]), (309, [3]), (4903, [3, 1, 0])],
#   [(31, [(1, 0.59553236), (3, 0.33936894)]),
#    (57, [(0, 0.21129173), (3, 0.7886507)]),
#    (70, [(0, 0.9977761)]),
#    (309, [(3, 0.9998796)]),
#    (4903, [(0, 0.046612613), (1, 0.060923487), (3, 0.4648693)])]),
#  ([(0, 0.76135826), (1, 0.07817847), (2, 0.079942375), (3, 0.08052086)],
#   [(1357, [0]), (1823, [0]), (4904, [0, 3, 2])],
#   [(1357, [(0, 0.9996633)]),
#    (1823, [(0, 0.9997222)]),
#    (4904, [(0, 0.26496568), (2, 0.013823494), (3, 0.015579889)])]),
#  ([(0, 0.054201413), (1, 0.054504402), (2, 0.5770927), (3, 0.31420147)],
#   [(409, [2]), (1590, [3]), (1764, [2]), (4905, [2, 3])],
#   [(409, [(2, 0.9999692)]),
#    (1590, [(3, 0.99515885)]),
#    (1764, [(2, 0.99907684)]),
#    (4905, [(2, 0.41780114), (3, 0.20770103)])]),
#  ([(0, 0.13618833), (1, 0.13827047), (2, 0.026198989), (3, 0.6993422)],
#   [(1, [0]),
#    (55, [3]),
#    (73, [3]),
#    (80, [3]),
#    (822, [3]),
#    (836, [1]),
#    (3640, [3, 0, 1]),
#    (4743, [3, 1]),
#    (4906, [3, 1, 0])],
#   [(1, [(0, 0.99981827)]),
#    (55, [(3, 0.99998075)]),
#    (73, [(3, 0.99986583)]),
#    (80, [(3, 0.9999473)]),
#    (822, [(3, 0.9999396)]),
#    (836, [(1, 0.9973441)]),
#    (3640, [(0, 0.045763243), (1, 0.025561217), (3, 0.83203244)]),
#    (4743, [(1, 0.0263521), (3, 0.7824649)]),
#    (4906, [(0, 0.016624702), (1, 0.042185742), (3, 0.9184657)])]),
#  ([(0, 0.19422254), (1, 0.20889935), (2, 0.22845219), (3, 0.3684259)],
#   [(4907, [3, 2, 1])],
#   [(4907, [(1, 0.025964221), (2, 0.051258575), (3, 0.23944047)])]),
#  ([(0, 0.1942843), (1, 0.2089943), (2, 0.22866221), (3, 0.36805916)],
#   [(4907, [3, 2, 1])],
#   [(4907, [(1, 0.026005285), (2, 0.051424332), (3, 0.23888889)])]),
#  ([(0, 0.64860916), (1, 0.104849726), (2, 0.11735982), (3, 0.12918124)],
#   [(146, [0]), (4908, [0, 3, 2])],
#   [(146, [(0, 0.99995023)]),
#    (4908, [(0, 0.34023336), (2, 0.037729166), (3, 0.06505718)])]),
#  ([(0, 0.7499951), (1, 0.08333489), (2, 0.08333498), (3, 0.083335)],
#   [(1, [0]), (90, [0])],
#   [(1, [(0, 0.9999925)]), (90, [(0, 0.9999556)])]),
#  ([(0, 0.8300146), (1, 0.055919282), (2, 0.056861684), (3, 0.057204496)],
#   [(89, [0]), (90, [0]), (4867, [0]), (4907, [0])],
#   [(89, [(0, 0.9999684)]),
#    (90, [(0, 1.9999233)]),
#    (4867, [(0, 0.2933375)]),
#    (4907, [(0, 0.2933375)])]),
#  ([(0, 0.42717355), (1, 0.031196715), (2, 0.18121253), (3, 0.36041716)],
#   [(73, [3]),
#    (80, [3]),
#    (549, [0]),
#    (1964, [0]),
#    (1973, [0]),
#    (2451, [2, 0]),
#    (4909, [3, 2, 0]),
#    (4910, [3, 2, 0])],
#   [(73, [(3, 0.9996034)]),
#    (80, [(3, 0.9998569)]),
#    (549, [(0, 0.9996597)]),
#    (1964, [(0, 0.9994136)]),
#    (1973, [(0, 0.99953663)]),
#    (2451, [(0, 0.028284514), (2, 0.9661719)]),
#    (4909, [(0, 0.091904566), (2, 0.12571423), (3, 0.33374426)]),
#    (4910, [(0, 0.091902465), (2, 0.12569158), (3, 0.33374682)])]),
#  ([(0, 0.88383394), (1, 0.03842805), (2, 0.038802896), (3, 0.03893513)],
#   [(216, [0]),
#    (404, [0]),
#    (517, [0]),
#    (837, [0]),
#    (3962, [0]),
#    (4911, [0]),
#    (4912, [0])],
#   [(216, [(0, 0.9998962)]),
#    (404, [(0, 0.99993575)]),
#    (517, [(0, 0.99995536)]),
#    (837, [(0, 0.99991286)]),
#    (3962, [(0, 0.9997391)]),
#    (4911, [(0, 0.31144607)]),
#    (4912, [(0, 0.31144607)])]),
#  ([(0, 0.21456265), (1, 0.042450238), (2, 0.04248285), (3, 0.70050424)],
#   [(13, [3]), (69, [3]), (73, [3]), (150, [0]), (4913, [3, 0])],
#   [(13, [(3, 0.9992081)]),
#    (69, [(3, 0.9999909)]),
#    (73, [(3, 0.9998766)]),
#    (150, [(0, 0.99973154)]),
#    (4913, [(0, 0.015971107), (3, 0.88325644)])]),
#  ([(0, 0.2522809), (1, 0.581014), (2, 0.14855425), (3, 0.018150916)],
#   [(28, [0]),
#    (172, [0]),
#    (405, [1]),
#    (430, [1]),
#    (835, [1]),
#    (1021, [2, 1, 0]),
#    (1080, [1]),
#    (1084, [0]),
#    (3100, [1]),
#    (3486, [1, 2, 0]),
#    (4914, [1, 2, 0]),
#    (4915, [1, 2, 0]),
#    (4916, [1, 2, 0])],
#   [(28, [(0, 0.999377)]),
#    (172, [(0, 0.9999238)]),
#    (405, [(1, 0.9995329)]),
#    (430, [(1, 0.9998682)]),
#    (835, [(1, 0.987725)]),
#    (1021, [(0, 0.12149739), (1, 0.46415213), (2, 1.4007154)]),
#    (1080, [(1, 1.9992868)]),
#    (1084, [(0, 0.99830145)]),
#    (3100, [(1, 0.99986655)]),
#    (3486, [(0, 0.052061636), (1, 0.39848092), (2, 0.11377688)]),
#    (4914, [(0, 0.053225763), (1, 0.38351646), (2, 0.1135859)]),
#    (4915, [(0, 0.053225763), (1, 0.38351646), (2, 0.1135859)]),
#    (4916, [(0, 0.053225763), (1, 0.38351646), (2, 0.1135859)])]),
#  ([(0, 0.03684529), (1, 0.18995796), (2, 0.507689), (3, 0.2655078)],
#   [(73, [3]),
#    (283, [1]),
#    (598, [2]),
#    (1229, [2]),
#    (2868, [2]),
#    (4913, [3, 2, 1])],
#   [(73, [(3, 0.99903244)]),
#    (283, [(1, 0.9985842)]),
#    (598, [(2, 0.99738383)]),
#    (1229, [(2, 0.9995219)]),
#    (2868, [(2, 0.9997227)]),
#    (4913, [(1, 0.040762253), (2, 0.20392898), (3, 0.555181)])]),
#  ...]

# %%
from itertools import chain

# %%
scores = list(chain(*[[score for topic_id,score in topic] \
                      for topic in [doc for doc in lda_corpus]]))

threshold = sum(scores)/len(scores)
print(threshold)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 scores = list(chain(*[[score for topic_id,score in topic] \
#       2                       for topic in [doc for doc in lda_corpus]]))
#       4 threshold = sum(scores)/len(scores)
#       5 print(threshold)
#
# Input In [65], in <listcomp>(.0)
# ----> 1 scores = list(chain(*[[score for topic_id,score in topic] \
#       2                       for topic in [doc for doc in lda_corpus]]))
#       4 threshold = sum(scores)/len(scores)
#       5 print(threshold)
#
# Input In [65], in <listcomp>(.0)
# ----> 1 scores = list(chain(*[[score for topic_id,score in topic] \
#       2                       for topic in [doc for doc in lda_corpus]]))
#       4 threshold = sum(scores)/len(scores)
#       5 print(threshold)
#
# ValueError: too many values to unpack (expected 2)

# %%
import numpy

# %%
 numpy.dot(numpy.ones([2, 2]), numpy.ones([4, ])).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 numpy.dot(numpy.ones([2, 2]), numpy.ones([4, ])).shape
#
# File <__array_function__ internals>:5, in dot(*args, **kwargs)
#
# ValueError: shapes (2,2) and (4,) not aligned: 2 (dim 1) != 4 (dim 0)

# %%
scores = []
for doc in lda_corpus:
    for topic in doc:
        for topic_id, score in topic:
            scores.append(score)
threshold = sum(scores)/len(scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 6>()
#       4         for topic_id, score in topic:
#       5             scores.append(score)
# ----> 6 threshold = sum(scores)/len(scores)
#
# ValueError: operands could not be broadcast together with shapes (2,2) (4,)
